# %%
from stable_baselines3 import PPO

import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print(x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('t_state_data_site_202405011106.csv')

# Parse the 'timestamp' column to datetime if needed
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Check the first few rows of the dataframe
display(df.head())
# Out:
#        id  site_id           timestamp  asc_power_kva  \
# 0  275985      753 2023-02-13 06:30:00          400.0
# 1  325596      753 2023-06-10 04:00:00          400.0
# 2  325597      753 2023-06-10 04:30:00          400.0
# 3  325598      753 2023-06-10 05:00:00          400.0
# 4  325599      753 2023-06-10 05:30:00          400.0
#
#    total_power_capacity_kw  forecast_non_ev_power_kw  \
# 0                      NaN                141.428452
# 1                      NaN                184.829665
# 2                      NaN                186.325789
# 3                      NaN                178.370818
# 4                      NaN                181.848093
#
#    forecast_headroom_power_kw  electricity_price  actual_total_power_kw  \
# 0                  258.571548           0.108902                    NaN
# 1                  215.170335           0.111245                    NaN
# 2                  213.674211           0.111245                    NaN
# 3                  221.629182           0.111245                    NaN
# 4                  218.151907           0.111245                    NaN
#
#    scheduled_total_power_kw  no_of_available_chargers_11kw  \
# 0                       NaN                              8
# 1                       NaN                              8
# 2                       NaN                              8
# 3                       NaN                              8
# 4                       NaN                              8
#
#    no_of_available_chargers_7kw  no_of_available_chargers_50kw  time_slot_no  \
# 0                           NaN                            NaN           NaN
# 1                           NaN                            NaN           NaN
# 2                           NaN                            NaN           NaN
# 3                           NaN                            NaN           NaN
# 4                           NaN                            NaN           NaN
#
#    base_time_slot_no
# 0               24.0
# 1               19.0
# 2               20.0
# 3               21.0
# 4               22.0

# %%
import gymnasium as gym
import numpy as np
import pandas as pd
import random

class EVChargingEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, df):
        super(EVChargingEnv, self).__init__()
        self.df = df
        self.battery_capacity = 75.0  # Maximum battery capacity in kWh
        self.battery_level = random.randint(35, 75)
        self.max_draw = 22.0  # Max charger capacity in kW
        self.dt = 1.0  # Time step in hours
        self.deadline = 24.0  # 24 hours until full charge needed
        self.targer_soc = 95
        self.session_price = 0

        # Define action and observation space
        self.action_space = gym.spaces.Box(low=np.array([0], dtype=np.float32), 
                                           high=np.array([self.max_draw], dtype=np.float32), dtype=np.float32)
        self.observation_space = gym.spaces.Box(low=np.array([0, 0, 0], dtype=np.float32), 
                                                high=np.array([self.targer_soc, 1, self.deadline], dtype=np.float32), 
                                                dtype=np.float32)

    def reset(self,seed=0):
        self.current_index = 0  # Start from the first row of the dataframe
        self.battery_level = random.randint(35, 75)
        self.time = 0.0
        row = self.df.iloc[self.current_index]
        self.current_price = row['electricity_price']
        self.session_price = 0
        return np.array([self.battery_level, self.current_price, self.time], dtype=np.float32), {}

    def step(self, action):
        charge_power = action[0]

        reward = 0
        added_soc = (charge_power * 0.5 * 100) / self.battery_capacity

        if self.battery_level > 94 and charge_power == 0:
            reward += 100
        elif self.battery_level > 94 and charge_power > 0:
            reward -= 100

        self.battery_level += added_soc
        reward -= 95 - self.battery_level
        
        if self.time >= self.deadline-1:
            reward -= 1000

        self.time += self.dt
        self.current_index = min(self.current_index + 1, len(self.df) - 1)  # Update index, preventing overflow
        row = self.df.iloc[self.current_index]
        self.current_price = row['electricity_price']

        self.session_price += self.current_price * 0.5 * charge_power

        done = self.time >= self.deadline # or self.battery_level >= self.max_battery

        trunc = False

        return np.array([self.battery_level, self.current_price, self.time], dtype=np.float32), reward, bool(done), trunc, {}

    def render(self, mode='human'):
        print(f'Time: {self.time}, Battery Level: {self.battery_level:.2f} %, Price: ${self.current_price:.3f} per kWh')

# %%
from stable_baselines3 import TD3
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.noise import NormalActionNoise

# Check the environment
env = EVChargingEnv(df)
check_env(env)

# Create the TD3 agent
n_actions = env.action_space.shape[0]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
model = TD3("MlpPolicy", env, action_noise=action_noise, verbose=1)

# Train the model
model.learn(total_timesteps=10000)

# Save the model
model.save("td3_ev_charging")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -456     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 4097     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 96       |
# ---------------------------------
# /Users/karankaushik/miniconda/envs/mlEnv/lib/python3.10/site-packages/stable_baselines3/common/env_checker.py:441: UserWarning: We recommend you to use a symmetric and normalized Box action space (range=[-1, 1]) cf. https://stable-baselines3.readthedocs.io/en/master/guide/rl_tips.html
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -411     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 229      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 192      |
# | train/             |          |
# |    actor_loss      | 1.3      |
# |    critic_loss     | 4.59e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 72       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -561     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 151      |
# |    time_elapsed    | 1        |
# |    total_timesteps | 288      |
# | train/             |          |
# |    actor_loss      | 14.5     |
# |    critic_loss     | 2.78e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 168      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -644     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 132      |
# |    time_elapsed    | 2        |
# |    total_timesteps | 384      |
# | train/             |          |
# |    actor_loss      | 20.4     |
# |    critic_loss     | 2.01e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 264      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -688     |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 122      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 480      |
# | train/             |          |
# |    actor_loss      | 31.6     |
# |    critic_loss     | 1.45e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 360      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -689     |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 117      |
# |    time_elapsed    | 4        |
# |    total_timesteps | 576      |
# | train/             |          |
# |    actor_loss      | 36.4     |
# |    critic_loss     | 1.32e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 456      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -734     |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 113      |
# |    time_elapsed    | 5        |
# |    total_timesteps | 672      |
# | train/             |          |
# |    actor_loss      | 39.3     |
# |    critic_loss     | 1.09e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 552      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -714     |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 110      |
# |    time_elapsed    | 6        |
# |    total_timesteps | 768      |
# | train/             |          |
# |    actor_loss      | 41.5     |
# |    critic_loss     | 923      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 648      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -732     |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 109      |
# |    time_elapsed    | 7        |
# |    total_timesteps | 864      |
# | train/             |          |
# |    actor_loss      | 43.9     |
# |    critic_loss     | 849      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 744      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -729     |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 107      |
# |    time_elapsed    | 8        |
# |    total_timesteps | 960      |
# | train/             |          |
# |    actor_loss      | 48.5     |
# |    critic_loss     | 847      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 840      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -730     |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 105      |
# |    time_elapsed    | 9        |
# |    total_timesteps | 1056     |
# | train/             |          |
# |    actor_loss      | 52       |
# |    critic_loss     | 797      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 936      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -735     |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 104      |
# |    time_elapsed    | 11       |
# |    total_timesteps | 1152     |
# | train/             |          |
# |    actor_loss      | 57.4     |
# |    critic_loss     | 780      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1032     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -750     |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 103      |
# |    time_elapsed    | 12       |
# |    total_timesteps | 1248     |
# | train/             |          |
# |    actor_loss      | 62       |
# |    critic_loss     | 1e+03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1128     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -768     |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 102      |
# |    time_elapsed    | 13       |
# |    total_timesteps | 1344     |
# | train/             |          |
# |    actor_loss      | 69.2     |
# |    critic_loss     | 748      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1224     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -756     |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 102      |
# |    time_elapsed    | 14       |
# |    total_timesteps | 1440     |
# | train/             |          |
# |    actor_loss      | 72.6     |
# |    critic_loss     | 948      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1320     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -761     |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 102      |
# |    time_elapsed    | 15       |
# |    total_timesteps | 1536     |
# | train/             |          |
# |    actor_loss      | 78.7     |
# |    critic_loss     | 922      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1416     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -776     |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 101      |
# |    time_elapsed    | 16       |
# |    total_timesteps | 1632     |
# | train/             |          |
# |    actor_loss      | 84       |
# |    critic_loss     | 1.04e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1512     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -779     |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 101      |
# |    time_elapsed    | 17       |
# |    total_timesteps | 1728     |
# | train/             |          |
# |    actor_loss      | 93.7     |
# |    critic_loss     | 894      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1608     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -775     |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 100      |
# |    time_elapsed    | 18       |
# |    total_timesteps | 1824     |
# | train/             |          |
# |    actor_loss      | 97       |
# |    critic_loss     | 823      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1704     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -778     |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 100      |
# |    time_elapsed    | 19       |
# |    total_timesteps | 1920     |
# | train/             |          |
# |    actor_loss      | 104      |
# |    critic_loss     | 853      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1800     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -783     |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 100      |
# |    time_elapsed    | 20       |
# |    total_timesteps | 2016     |
# | train/             |          |
# |    actor_loss      | 107      |
# |    critic_loss     | 842      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1896     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -779     |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 100      |
# |    time_elapsed    | 21       |
# |    total_timesteps | 2112     |
# | train/             |          |
# |    actor_loss      | 115      |
# |    critic_loss     | 824      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1992     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -780     |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 99       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 2208     |
# | train/             |          |
# |    actor_loss      | 122      |
# |    critic_loss     | 879      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2088     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -783     |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 99       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 2304     |
# | train/             |          |
# |    actor_loss      | 126      |
# |    critic_loss     | 1.06e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2184     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -783     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 99       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 2400     |
# | train/             |          |
# |    actor_loss      | 132      |
# |    critic_loss     | 914      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2280     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -800     |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 99       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 2496     |
# | train/             |          |
# |    actor_loss      | 140      |
# |    critic_loss     | 943      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2376     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -818     |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 99       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 2592     |
# | train/             |          |
# |    actor_loss      | 145      |
# |    critic_loss     | 823      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2472     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -822     |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 99       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 2688     |
# | train/             |          |
# |    actor_loss      | 154      |
# |    critic_loss     | 1.05e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2568     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -819     |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 98       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 2784     |
# | train/             |          |
# |    actor_loss      | 156      |
# |    critic_loss     | 884      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2664     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -815     |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 98       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 2880     |
# | train/             |          |
# |    actor_loss      | 166      |
# |    critic_loss     | 978      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2760     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -828     |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 98       |
# |    time_elapsed    | 30       |
# |    total_timesteps | 2976     |
# | train/             |          |
# |    actor_loss      | 171      |
# |    critic_loss     | 1.3e+03  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2856     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -828     |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 98       |
# |    time_elapsed    | 31       |
# |    total_timesteps | 3072     |
# | train/             |          |
# |    actor_loss      | 175      |
# |    critic_loss     | 963      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2952     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -836     |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 98       |
# |    time_elapsed    | 32       |
# |    total_timesteps | 3168     |
# | train/             |          |
# |    actor_loss      | 180      |
# |    critic_loss     | 1.02e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3048     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -843     |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 98       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 3264     |
# | train/             |          |
# |    actor_loss      | 188      |
# |    critic_loss     | 905      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3144     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -846     |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 98       |
# |    time_elapsed    | 34       |
# |    total_timesteps | 3360     |
# | train/             |          |
# |    actor_loss      | 192      |
# |    critic_loss     | 752      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3240     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -854     |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 98       |
# |    time_elapsed    | 35       |
# |    total_timesteps | 3456     |
# | train/             |          |
# |    actor_loss      | 196      |
# |    critic_loss     | 895      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3336     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -856     |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 98       |
# |    time_elapsed    | 36       |
# |    total_timesteps | 3552     |
# | train/             |          |
# |    actor_loss      | 199      |
# |    critic_loss     | 1.15e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3432     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -855     |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 98       |
# |    time_elapsed    | 37       |
# |    total_timesteps | 3648     |
# | train/             |          |
# |    actor_loss      | 211      |
# |    critic_loss     | 1.04e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3528     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -851     |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 98       |
# |    time_elapsed    | 38       |
# |    total_timesteps | 3744     |
# | train/             |          |
# |    actor_loss      | 214      |
# |    critic_loss     | 1.44e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3624     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -866     |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 97       |
# |    time_elapsed    | 39       |
# |    total_timesteps | 3840     |
# | train/             |          |
# |    actor_loss      | 218      |
# |    critic_loss     | 898      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3720     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -872     |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 97       |
# |    time_elapsed    | 40       |
# |    total_timesteps | 3936     |
# | train/             |          |
# |    actor_loss      | 221      |
# |    critic_loss     | 864      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3816     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -851     |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 97       |
# |    time_elapsed    | 41       |
# |    total_timesteps | 4032     |
# | train/             |          |
# |    actor_loss      | 223      |
# |    critic_loss     | 1.05e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 3912     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -855     |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 97       |
# |    time_elapsed    | 42       |
# |    total_timesteps | 4128     |
# | train/             |          |
# |    actor_loss      | 227      |
# |    critic_loss     | 756      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4008     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -855     |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 97       |
# |    time_elapsed    | 43       |
# |    total_timesteps | 4224     |
# | train/             |          |
# |    actor_loss      | 238      |
# |    critic_loss     | 1.25e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4104     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -863     |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 97       |
# |    time_elapsed    | 44       |
# |    total_timesteps | 4320     |
# | train/             |          |
# |    actor_loss      | 240      |
# |    critic_loss     | 883      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4200     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -870     |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 97       |
# |    time_elapsed    | 45       |
# |    total_timesteps | 4416     |
# | train/             |          |
# |    actor_loss      | 239      |
# |    critic_loss     | 1.24e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4296     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -884     |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 97       |
# |    time_elapsed    | 46       |
# |    total_timesteps | 4512     |
# | train/             |          |
# |    actor_loss      | 249      |
# |    critic_loss     | 956      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4392     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -882     |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 97       |
# |    time_elapsed    | 47       |
# |    total_timesteps | 4608     |
# | train/             |          |
# |    actor_loss      | 251      |
# |    critic_loss     | 1.03e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4488     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -888     |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 97       |
# |    time_elapsed    | 48       |
# |    total_timesteps | 4704     |
# | train/             |          |
# |    actor_loss      | 255      |
# |    critic_loss     | 939      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4584     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -889     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 97       |
# |    time_elapsed    | 49       |
# |    total_timesteps | 4800     |
# | train/             |          |
# |    actor_loss      | 265      |
# |    critic_loss     | 925      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4680     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -890     |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 97       |
# |    time_elapsed    | 50       |
# |    total_timesteps | 4896     |
# | train/             |          |
# |    actor_loss      | 259      |
# |    critic_loss     | 1.03e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4776     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -889     |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 97       |
# |    time_elapsed    | 51       |
# |    total_timesteps | 4992     |
# | train/             |          |
# |    actor_loss      | 263      |
# |    critic_loss     | 1.25e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4872     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -880     |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 97       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 5088     |
# | train/             |          |
# |    actor_loss      | 268      |
# |    critic_loss     | 1.3e+03  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4968     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -882     |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 97       |
# |    time_elapsed    | 53       |
# |    total_timesteps | 5184     |
# | train/             |          |
# |    actor_loss      | 267      |
# |    critic_loss     | 804      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5064     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -886     |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 97       |
# |    time_elapsed    | 54       |
# |    total_timesteps | 5280     |
# | train/             |          |
# |    actor_loss      | 282      |
# |    critic_loss     | 1.03e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5160     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -881     |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 97       |
# |    time_elapsed    | 55       |
# |    total_timesteps | 5376     |
# | train/             |          |
# |    actor_loss      | 273      |
# |    critic_loss     | 956      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5256     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -876     |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 96       |
# |    time_elapsed    | 56       |
# |    total_timesteps | 5472     |
# | train/             |          |
# |    actor_loss      | 284      |
# |    critic_loss     | 1.08e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5352     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -875     |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 96       |
# |    time_elapsed    | 57       |
# |    total_timesteps | 5568     |
# | train/             |          |
# |    actor_loss      | 284      |
# |    critic_loss     | 813      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5448     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -874     |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 96       |
# |    time_elapsed    | 58       |
# |    total_timesteps | 5664     |
# | train/             |          |
# |    actor_loss      | 287      |
# |    critic_loss     | 1.32e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5544     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -863     |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 96       |
# |    time_elapsed    | 59       |
# |    total_timesteps | 5760     |
# | train/             |          |
# |    actor_loss      | 292      |
# |    critic_loss     | 1.1e+03  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5640     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -856     |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 96       |
# |    time_elapsed    | 60       |
# |    total_timesteps | 5856     |
# | train/             |          |
# |    actor_loss      | 293      |
# |    critic_loss     | 951      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5736     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -862     |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 96       |
# |    time_elapsed    | 61       |
# |    total_timesteps | 5952     |
# | train/             |          |
# |    actor_loss      | 298      |
# |    critic_loss     | 1.4e+03  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5832     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -862     |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 96       |
# |    time_elapsed    | 62       |
# |    total_timesteps | 6048     |
# | train/             |          |
# |    actor_loss      | 293      |
# |    critic_loss     | 1.19e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 5928     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -856     |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 96       |
# |    time_elapsed    | 63       |
# |    total_timesteps | 6144     |
# | train/             |          |
# |    actor_loss      | 297      |
# |    critic_loss     | 1.05e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6024     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -851     |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 96       |
# |    time_elapsed    | 64       |
# |    total_timesteps | 6240     |
# | train/             |          |
# |    actor_loss      | 296      |
# |    critic_loss     | 933      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6120     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -848     |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 96       |
# |    time_elapsed    | 65       |
# |    total_timesteps | 6336     |
# | train/             |          |
# |    actor_loss      | 303      |
# |    critic_loss     | 1.18e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6216     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -863     |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 96       |
# |    time_elapsed    | 66       |
# |    total_timesteps | 6432     |
# | train/             |          |
# |    actor_loss      | 309      |
# |    critic_loss     | 1.13e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6312     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -849     |
# | time/              |          |
# |    episodes        | 272      |
# |    fps             | 96       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 6528     |
# | train/             |          |
# |    actor_loss      | 303      |
# |    critic_loss     | 1.69e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6408     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -855     |
# | time/              |          |
# |    episodes        | 276      |
# |    fps             | 96       |
# |    time_elapsed    | 68       |
# |    total_timesteps | 6624     |
# | train/             |          |
# |    actor_loss      | 309      |
# |    critic_loss     | 1.55e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6504     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -843     |
# | time/              |          |
# |    episodes        | 280      |
# |    fps             | 96       |
# |    time_elapsed    | 69       |
# |    total_timesteps | 6720     |
# | train/             |          |
# |    actor_loss      | 311      |
# |    critic_loss     | 2.17e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6600     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -842     |
# | time/              |          |
# |    episodes        | 284      |
# |    fps             | 96       |
# |    time_elapsed    | 70       |
# |    total_timesteps | 6816     |
# | train/             |          |
# |    actor_loss      | 310      |
# |    critic_loss     | 911      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6696     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -834     |
# | time/              |          |
# |    episodes        | 288      |
# |    fps             | 96       |
# |    time_elapsed    | 71       |
# |    total_timesteps | 6912     |
# | train/             |          |
# |    actor_loss      | 322      |
# |    critic_loss     | 999      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6792     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -843     |
# | time/              |          |
# |    episodes        | 292      |
# |    fps             | 96       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 7008     |
# | train/             |          |
# |    actor_loss      | 321      |
# |    critic_loss     | 1.96e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6888     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -826     |
# | time/              |          |
# |    episodes        | 296      |
# |    fps             | 96       |
# |    time_elapsed    | 73       |
# |    total_timesteps | 7104     |
# | train/             |          |
# |    actor_loss      | 324      |
# |    critic_loss     | 1.2e+03  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 6984     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -831     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 96       |
# |    time_elapsed    | 74       |
# |    total_timesteps | 7200     |
# | train/             |          |
# |    actor_loss      | 312      |
# |    critic_loss     | 1.02e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7080     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -830     |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 96       |
# |    time_elapsed    | 75       |
# |    total_timesteps | 7296     |
# | train/             |          |
# |    actor_loss      | 325      |
# |    critic_loss     | 2.29e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7176     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -831     |
# | time/              |          |
# |    episodes        | 308      |
# |    fps             | 96       |
# |    time_elapsed    | 76       |
# |    total_timesteps | 7392     |
# | train/             |          |
# |    actor_loss      | 322      |
# |    critic_loss     | 1.87e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7272     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -829     |
# | time/              |          |
# |    episodes        | 312      |
# |    fps             | 96       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 7488     |
# | train/             |          |
# |    actor_loss      | 334      |
# |    critic_loss     | 1.22e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7368     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -829     |
# | time/              |          |
# |    episodes        | 316      |
# |    fps             | 96       |
# |    time_elapsed    | 78       |
# |    total_timesteps | 7584     |
# | train/             |          |
# |    actor_loss      | 323      |
# |    critic_loss     | 1.01e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7464     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -826     |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 96       |
# |    time_elapsed    | 79       |
# |    total_timesteps | 7680     |
# | train/             |          |
# |    actor_loss      | 329      |
# |    critic_loss     | 1.57e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7560     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -830     |
# | time/              |          |
# |    episodes        | 324      |
# |    fps             | 96       |
# |    time_elapsed    | 80       |
# |    total_timesteps | 7776     |
# | train/             |          |
# |    actor_loss      | 330      |
# |    critic_loss     | 2.4e+03  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7656     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -828     |
# | time/              |          |
# |    episodes        | 328      |
# |    fps             | 96       |
# |    time_elapsed    | 81       |
# |    total_timesteps | 7872     |
# | train/             |          |
# |    actor_loss      | 326      |
# |    critic_loss     | 2.27e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7752     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -837     |
# | time/              |          |
# |    episodes        | 332      |
# |    fps             | 96       |
# |    time_elapsed    | 82       |
# |    total_timesteps | 7968     |
# | train/             |          |
# |    actor_loss      | 339      |
# |    critic_loss     | 1.33e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7848     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -822     |
# | time/              |          |
# |    episodes        | 336      |
# |    fps             | 96       |
# |    time_elapsed    | 83       |
# |    total_timesteps | 8064     |
# | train/             |          |
# |    actor_loss      | 339      |
# |    critic_loss     | 1.02e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 7944     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -829     |
# | time/              |          |
# |    episodes        | 340      |
# |    fps             | 96       |
# |    time_elapsed    | 84       |
# |    total_timesteps | 8160     |
# | train/             |          |
# |    actor_loss      | 335      |
# |    critic_loss     | 2.35e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8040     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -825     |
# | time/              |          |
# |    episodes        | 344      |
# |    fps             | 96       |
# |    time_elapsed    | 85       |
# |    total_timesteps | 8256     |
# | train/             |          |
# |    actor_loss      | 341      |
# |    critic_loss     | 1.42e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8136     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -832     |
# | time/              |          |
# |    episodes        | 348      |
# |    fps             | 96       |
# |    time_elapsed    | 86       |
# |    total_timesteps | 8352     |
# | train/             |          |
# |    actor_loss      | 340      |
# |    critic_loss     | 1.14e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8232     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -829     |
# | time/              |          |
# |    episodes        | 352      |
# |    fps             | 96       |
# |    time_elapsed    | 87       |
# |    total_timesteps | 8448     |
# | train/             |          |
# |    actor_loss      | 334      |
# |    critic_loss     | 2.23e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8328     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -838     |
# | time/              |          |
# |    episodes        | 356      |
# |    fps             | 96       |
# |    time_elapsed    | 88       |
# |    total_timesteps | 8544     |
# | train/             |          |
# |    actor_loss      | 342      |
# |    critic_loss     | 2.23e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8424     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -843     |
# | time/              |          |
# |    episodes        | 360      |
# |    fps             | 96       |
# |    time_elapsed    | 89       |
# |    total_timesteps | 8640     |
# | train/             |          |
# |    actor_loss      | 341      |
# |    critic_loss     | 1.3e+03  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8520     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -844     |
# | time/              |          |
# |    episodes        | 364      |
# |    fps             | 96       |
# |    time_elapsed    | 90       |
# |    total_timesteps | 8736     |
# | train/             |          |
# |    actor_loss      | 342      |
# |    critic_loss     | 971      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8616     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -848     |
# | time/              |          |
# |    episodes        | 368      |
# |    fps             | 96       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 8832     |
# | train/             |          |
# |    actor_loss      | 339      |
# |    critic_loss     | 1.15e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8712     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -861     |
# | time/              |          |
# |    episodes        | 372      |
# |    fps             | 96       |
# |    time_elapsed    | 92       |
# |    total_timesteps | 8928     |
# | train/             |          |
# |    actor_loss      | 348      |
# |    critic_loss     | 988      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8808     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -857     |
# | time/              |          |
# |    episodes        | 376      |
# |    fps             | 96       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 9024     |
# | train/             |          |
# |    actor_loss      | 353      |
# |    critic_loss     | 1.05e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8904     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -862     |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 96       |
# |    time_elapsed    | 94       |
# |    total_timesteps | 9120     |
# | train/             |          |
# |    actor_loss      | 350      |
# |    critic_loss     | 1.26e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9000     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -865     |
# | time/              |          |
# |    episodes        | 384      |
# |    fps             | 96       |
# |    time_elapsed    | 95       |
# |    total_timesteps | 9216     |
# | train/             |          |
# |    actor_loss      | 352      |
# |    critic_loss     | 1.44e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9096     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -855     |
# | time/              |          |
# |    episodes        | 388      |
# |    fps             | 96       |
# |    time_elapsed    | 96       |
# |    total_timesteps | 9312     |
# | train/             |          |
# |    actor_loss      | 346      |
# |    critic_loss     | 1.52e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9192     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -848     |
# | time/              |          |
# |    episodes        | 392      |
# |    fps             | 96       |
# |    time_elapsed    | 97       |
# |    total_timesteps | 9408     |
# | train/             |          |
# |    actor_loss      | 344      |
# |    critic_loss     | 2.44e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9288     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -860     |
# | time/              |          |
# |    episodes        | 396      |
# |    fps             | 96       |
# |    time_elapsed    | 98       |
# |    total_timesteps | 9504     |
# | train/             |          |
# |    actor_loss      | 350      |
# |    critic_loss     | 1.31e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9384     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -858     |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 96       |
# |    time_elapsed    | 99       |
# |    total_timesteps | 9600     |
# | train/             |          |
# |    actor_loss      | 351      |
# |    critic_loss     | 1.11e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9480     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -854     |
# | time/              |          |
# |    episodes        | 404      |
# |    fps             | 96       |
# |    time_elapsed    | 100      |
# |    total_timesteps | 9696     |
# | train/             |          |
# |    actor_loss      | 352      |
# |    critic_loss     | 1.18e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9576     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -861     |
# | time/              |          |
# |    episodes        | 408      |
# |    fps             | 96       |
# |    time_elapsed    | 101      |
# |    total_timesteps | 9792     |
# | train/             |          |
# |    actor_loss      | 353      |
# |    critic_loss     | 883      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9672     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -876     |
# | time/              |          |
# |    episodes        | 412      |
# |    fps             | 96       |
# |    time_elapsed    | 102      |
# |    total_timesteps | 9888     |
# | train/             |          |
# |    actor_loss      | 355      |
# |    critic_loss     | 2.16e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9768     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -861     |
# | time/              |          |
# |    episodes        | 416      |
# |    fps             | 96       |
# |    time_elapsed    | 103      |
# |    total_timesteps | 9984     |
# | train/             |          |
# |    actor_loss      | 345      |
# |    critic_loss     | 883      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 9864     |
# ---------------------------------

# %%
obs, reward, done,trunc, _ = env.step([9])  # Unpack and use only the observation for the next predict call
env.render()
# Out:
# Time: 1.0, Battery Level: 44.00 %, Price: $0.111 per kWh

# %%
obs, _ = env.reset()  # Unpack to get only the observation
for _ in range(100):
    action, _states = model.predict(obs, deterministic=True)
    print(f'Charge at {action[0]} kwh')
    obs, reward, done,trunc, _ = env.step(action)  # Unpack and use only the observation for the next predict call
    env.render()
    print(f'Reward {reward}')
    if done:
        obs, _ = env.reset()  # Reset the environment and unpack the observation
# Out:
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 63.00 %, Price: $0.111 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 63.00 %, Price: $0.111 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 63.00 %, Price: $0.111 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 63.00 %, Price: $0.111 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 5.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 6.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 7.0, Battery Level: 63.00 %, Price: $0.109 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 8.0, Battery Level: 63.00 %, Price: $0.111 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 9.0, Battery Level: 63.00 %, Price: $0.111 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 10.0, Battery Level: 63.00 %, Price: $0.111 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 11.0, Battery Level: 63.00 %, Price: $0.111 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 12.0, Battery Level: 63.00 %, Price: $0.109 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 13.0, Battery Level: 63.00 %, Price: $0.109 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 14.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 15.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 16.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 17.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 18.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 19.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 20.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 21.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 22.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 23.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 24.0, Battery Level: 63.00 %, Price: $0.143 per kWh
# Reward -32.0
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 66.00 %, Price: $0.111 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 66.00 %, Price: $0.111 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 66.00 %, Price: $0.111 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 66.00 %, Price: $0.111 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 5.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 6.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 7.0, Battery Level: 66.00 %, Price: $0.109 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 8.0, Battery Level: 66.00 %, Price: $0.111 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 9.0, Battery Level: 66.00 %, Price: $0.111 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 10.0, Battery Level: 66.00 %, Price: $0.111 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 11.0, Battery Level: 66.00 %, Price: $0.111 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 12.0, Battery Level: 66.00 %, Price: $0.109 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 13.0, Battery Level: 66.00 %, Price: $0.109 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 14.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 15.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 16.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 17.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 18.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 19.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 20.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 21.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 22.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 23.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 24.0, Battery Level: 66.00 %, Price: $0.143 per kWh
# Reward -29.0
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 50.00 %, Price: $0.111 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 50.00 %, Price: $0.111 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 50.00 %, Price: $0.111 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 50.00 %, Price: $0.111 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 5.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 6.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 7.0, Battery Level: 50.00 %, Price: $0.109 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 8.0, Battery Level: 50.00 %, Price: $0.111 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 9.0, Battery Level: 50.00 %, Price: $0.111 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 10.0, Battery Level: 50.00 %, Price: $0.111 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 11.0, Battery Level: 50.00 %, Price: $0.111 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 12.0, Battery Level: 50.00 %, Price: $0.109 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 13.0, Battery Level: 50.00 %, Price: $0.109 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 14.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 15.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 16.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 17.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 18.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 19.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 20.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 21.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 22.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 23.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 24.0, Battery Level: 50.00 %, Price: $0.143 per kWh
# Reward -45.0
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 68.00 %, Price: $0.111 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 68.00 %, Price: $0.111 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 68.00 %, Price: $0.111 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 68.00 %, Price: $0.111 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 5.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 6.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 7.0, Battery Level: 68.00 %, Price: $0.109 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 8.0, Battery Level: 68.00 %, Price: $0.111 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 9.0, Battery Level: 68.00 %, Price: $0.111 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 10.0, Battery Level: 68.00 %, Price: $0.111 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 11.0, Battery Level: 68.00 %, Price: $0.111 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 12.0, Battery Level: 68.00 %, Price: $0.109 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 13.0, Battery Level: 68.00 %, Price: $0.109 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 14.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 15.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 16.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 17.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 18.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 19.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 20.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 21.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 22.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 23.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 24.0, Battery Level: 68.00 %, Price: $0.143 per kWh
# Reward -27.0
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 60.00 %, Price: $0.111 per kWh
# Reward -35.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 60.00 %, Price: $0.111 per kWh
# Reward -35.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 60.00 %, Price: $0.111 per kWh
# Reward -35.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 60.00 %, Price: $0.111 per kWh
# Reward -35.0
