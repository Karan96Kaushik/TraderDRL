# %%
from stable_baselines3 import PPO

import torch
if torch.backends.mps.is_available():
    mps_device = torch.device("mps")
    x = torch.ones(1, device=mps_device)
    print(x)
else:
    print ("MPS device not found.")
# Out:
# tensor([1.], device='mps:0')

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('t_state_data_site_202405011106.csv')

# Parse the 'timestamp' column to datetime if needed
df['timestamp'] = pd.to_datetime(df['timestamp'])

# Check the first few rows of the dataframe
display(df.head())
# Out:
#        id  site_id           timestamp  asc_power_kva  \
# 0  275985      753 2023-02-13 06:30:00          400.0
# 1  325596      753 2023-06-10 04:00:00          400.0
# 2  325597      753 2023-06-10 04:30:00          400.0
# 3  325598      753 2023-06-10 05:00:00          400.0
# 4  325599      753 2023-06-10 05:30:00          400.0
#
#    total_power_capacity_kw  forecast_non_ev_power_kw  \
# 0                      NaN                141.428452
# 1                      NaN                184.829665
# 2                      NaN                186.325789
# 3                      NaN                178.370818
# 4                      NaN                181.848093
#
#    forecast_headroom_power_kw  electricity_price  actual_total_power_kw  \
# 0                  258.571548           0.108902                    NaN
# 1                  215.170335           0.111245                    NaN
# 2                  213.674211           0.111245                    NaN
# 3                  221.629182           0.111245                    NaN
# 4                  218.151907           0.111245                    NaN
#
#    scheduled_total_power_kw  no_of_available_chargers_11kw  \
# 0                       NaN                              8
# 1                       NaN                              8
# 2                       NaN                              8
# 3                       NaN                              8
# 4                       NaN                              8
#
#    no_of_available_chargers_7kw  no_of_available_chargers_50kw  time_slot_no  \
# 0                           NaN                            NaN           NaN
# 1                           NaN                            NaN           NaN
# 2                           NaN                            NaN           NaN
# 3                           NaN                            NaN           NaN
# 4                           NaN                            NaN           NaN
#
#    base_time_slot_no
# 0               24.0
# 1               19.0
# 2               20.0
# 3               21.0
# 4               22.0

# %%
import gymnasium as gym
import numpy as np
import pandas as pd
import random

class EVChargingEnv(gym.Env):
    metadata = {'render.modes': ['human']}

    def __init__(self, df):
        super(EVChargingEnv, self).__init__()
        self.df = df
        self.battery_capacity = 75.0  # Maximum battery capacity in kWh
        self.battery_level = random.randint(35, 75)
        self.max_draw = 22.0  # Max charger capacity in kW
        self.dt = 1.0  # Time step in hours
        self.deadline = 24.0  # 24 hours until full charge needed
        self.targer_soc = 95
        self.session_price = 0

        # Define action and observation space
        self.action_space = gym.spaces.Box(low=np.array([0], dtype=np.float32), 
                                           high=np.array([self.max_draw], dtype=np.float32), dtype=np.float32)
        self.observation_space = gym.spaces.Box(low=np.array([0, 0, 0], dtype=np.float32), 
                                                high=np.array([self.targer_soc, 1, self.deadline], dtype=np.float32), 
                                                dtype=np.float32)

    def reset(self,seed=0):
        self.current_index = 0  # Start from the first row of the dataframe
        self.battery_level = random.randint(35, 75)
        self.time = 0.0
        row = self.df.iloc[self.current_index]
        self.current_price = row['electricity_price']
        self.session_price = 0
        return np.array([self.battery_level, self.current_price, self.time], dtype=np.float32), {}

    def step(self, action):
        charge_power = action[0]

        reward = 0
        added_soc = (charge_power * 0.5 * 100) / self.battery_capacity

        if self.battery_level > 94 and charge_power == 0:
            reward += 100
        elif self.battery_level > 94 and charge_power > 0:
            reward -= 100

        self.battery_level += added_soc
        reward -= 95 - min(self.battery_level, 95)
        
        if (self.time >= self.deadline-1 and self.battery_level < 95):
            reward -= 300

        self.time += self.dt
        self.current_index = min(self.current_index + 1, len(self.df) - 1)  # Update index, preventing overflow
        row = self.df.iloc[self.current_index]
        self.current_price = row['electricity_price']

        self.session_price += self.current_price * 0.5 * charge_power

        done = self.time >= self.deadline # or self.battery_level >= self.max_battery

        trunc = self.battery_level > 94
        # if self.battery_level > 94:
        #     trunc

        return np.array([self.battery_level, self.current_price, self.time], dtype=np.float32), reward, bool(done), bool(trunc), {}

    def render(self, mode='human'):
        print(f'Time: {self.time}, Battery Level: {self.battery_level:.2f} %, Price: ${self.current_price:.3f} per kWh')

# %%
from stable_baselines3 import TD3
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.noise import NormalActionNoise

# Check the environment
env = EVChargingEnv(df)
check_env(env)

# Create the TD3 agent
n_actions = env.action_space.shape[0]
action_noise = NormalActionNoise(mean=np.zeros(n_actions), sigma=0.1 * np.ones(n_actions))
device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"Using device: {device}")

model = TD3("MlpPolicy", env, action_noise=action_noise, verbose=1, device=device)

# Train the model
model.learn(total_timesteps=100000)

# Save the model
model.save("td3_ev_charging")
# Out:
# Using mps device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 6.25     |
# |    ep_rew_mean     | -132     |
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 2684     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 25       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.75     |
# |    ep_rew_mean     | -105     |
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 2634     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 46       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.83     |
# |    ep_rew_mean     | -112     |
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 2471     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 70       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.75     |
# |    ep_rew_mean     | -111     |
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 2540     |
# |    time_elapsed    | 0        |
# |    total_timesteps | 92       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.4      |
# |    ep_rew_mean     | -97.7    |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 278      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 108      |
# | train/             |          |
# |    actor_loss      | 27.8     |
# |    critic_loss     | 993      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8        |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 5.17     |
# |    ep_rew_mean     | -92.8    |
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 126      |
# |    time_elapsed    | 0        |
# |    total_timesteps | 124      |
# | train/             |          |
# |    actor_loss      | 25.7     |
# |    critic_loss     | 712      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 24       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.86     |
# |    ep_rew_mean     | -84.6    |
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 94       |
# |    time_elapsed    | 1        |
# |    total_timesteps | 136      |
# | train/             |          |
# |    actor_loss      | 21       |
# |    critic_loss     | 754      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 36       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.69     |
# |    ep_rew_mean     | -81      |
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 74       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 150      |
# | train/             |          |
# |    actor_loss      | 22.8     |
# |    critic_loss     | 692      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 52       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.53     |
# |    ep_rew_mean     | -76.7    |
# | time/              |          |
# |    episodes        | 36       |
# |    fps             | 67       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 163      |
# | train/             |          |
# |    actor_loss      | 23.7     |
# |    critic_loss     | 763      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 63       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.35     |
# |    ep_rew_mean     | -71.9    |
# | time/              |          |
# |    episodes        | 40       |
# |    fps             | 60       |
# |    time_elapsed    | 2        |
# |    total_timesteps | 174      |
# | train/             |          |
# |    actor_loss      | 22.8     |
# |    critic_loss     | 591      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 76       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.2      |
# |    ep_rew_mean     | -68.2    |
# | time/              |          |
# |    episodes        | 44       |
# |    fps             | 57       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 185      |
# | train/             |          |
# |    actor_loss      | 25.3     |
# |    critic_loss     | 649      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 84       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.1      |
# |    ep_rew_mean     | -65.9    |
# | time/              |          |
# |    episodes        | 48       |
# |    fps             | 53       |
# |    time_elapsed    | 3        |
# |    total_timesteps | 197      |
# | train/             |          |
# |    actor_loss      | 24.3     |
# |    critic_loss     | 622      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 97       |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.04     |
# |    ep_rew_mean     | -64.8    |
# | time/              |          |
# |    episodes        | 52       |
# |    fps             | 50       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 210      |
# | train/             |          |
# |    actor_loss      | 25.1     |
# |    critic_loss     | 479      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 110      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.02     |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 56       |
# |    fps             | 48       |
# |    time_elapsed    | 4        |
# |    total_timesteps | 225      |
# | train/             |          |
# |    actor_loss      | 25.2     |
# |    critic_loss     | 627      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 125      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 4.02     |
# |    ep_rew_mean     | -65      |
# | time/              |          |
# |    episodes        | 60       |
# |    fps             | 45       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 241      |
# | train/             |          |
# |    actor_loss      | 26.6     |
# |    critic_loss     | 622      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 142      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.94     |
# |    ep_rew_mean     | -62.8    |
# | time/              |          |
# |    episodes        | 64       |
# |    fps             | 43       |
# |    time_elapsed    | 5        |
# |    total_timesteps | 252      |
# | train/             |          |
# |    actor_loss      | 26.8     |
# |    critic_loss     | 546      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 154      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.93     |
# |    ep_rew_mean     | -62.8    |
# | time/              |          |
# |    episodes        | 68       |
# |    fps             | 43       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 267      |
# | train/             |          |
# |    actor_loss      | 25.4     |
# |    critic_loss     | 510      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 167      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.89     |
# |    ep_rew_mean     | -61.3    |
# | time/              |          |
# |    episodes        | 72       |
# |    fps             | 41       |
# |    time_elapsed    | 6        |
# |    total_timesteps | 280      |
# | train/             |          |
# |    actor_loss      | 31.1     |
# |    critic_loss     | 522      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 181      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.86     |
# |    ep_rew_mean     | -60.2    |
# | time/              |          |
# |    episodes        | 76       |
# |    fps             | 40       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 293      |
# | train/             |          |
# |    actor_loss      | 27.1     |
# |    critic_loss     | 494      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 194      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.84     |
# |    ep_rew_mean     | -59.8    |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 40       |
# |    time_elapsed    | 7        |
# |    total_timesteps | 307      |
# | train/             |          |
# |    actor_loss      | 29.2     |
# |    critic_loss     | 462      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 207      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.81     |
# |    ep_rew_mean     | -59.2    |
# | time/              |          |
# |    episodes        | 84       |
# |    fps             | 39       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 320      |
# | train/             |          |
# |    actor_loss      | 31.4     |
# |    critic_loss     | 503      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 220      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.78     |
# |    ep_rew_mean     | -58.5    |
# | time/              |          |
# |    episodes        | 88       |
# |    fps             | 38       |
# |    time_elapsed    | 8        |
# |    total_timesteps | 333      |
# | train/             |          |
# |    actor_loss      | 31       |
# |    critic_loss     | 500      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 234      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.79     |
# |    ep_rew_mean     | -59      |
# | time/              |          |
# |    episodes        | 92       |
# |    fps             | 38       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 349      |
# | train/             |          |
# |    actor_loss      | 32.5     |
# |    critic_loss     | 438      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 250      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.76     |
# |    ep_rew_mean     | -57.9    |
# | time/              |          |
# |    episodes        | 96       |
# |    fps             | 37       |
# |    time_elapsed    | 9        |
# |    total_timesteps | 361      |
# | train/             |          |
# |    actor_loss      | 34.2     |
# |    critic_loss     | 417      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 263      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.72     |
# |    ep_rew_mean     | -56.5    |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 37       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 372      |
# | train/             |          |
# |    actor_loss      | 30.7     |
# |    critic_loss     | 327      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 274      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.57     |
# |    ep_rew_mean     | -51.9    |
# | time/              |          |
# |    episodes        | 104      |
# |    fps             | 36       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 382      |
# | train/             |          |
# |    actor_loss      | 30.4     |
# |    critic_loss     | 352      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 284      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.5      |
# |    ep_rew_mean     | -51.1    |
# | time/              |          |
# |    episodes        | 108      |
# |    fps             | 36       |
# |    time_elapsed    | 10       |
# |    total_timesteps | 396      |
# | train/             |          |
# |    actor_loss      | 31.2     |
# |    critic_loss     | 309      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 297      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.39     |
# |    ep_rew_mean     | -47.8    |
# | time/              |          |
# |    episodes        | 112      |
# |    fps             | 36       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 409      |
# | train/             |          |
# |    actor_loss      | 32.9     |
# |    critic_loss     | 312      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 310      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.27     |
# |    ep_rew_mean     | -44.4    |
# | time/              |          |
# |    episodes        | 116      |
# |    fps             | 35       |
# |    time_elapsed    | 11       |
# |    total_timesteps | 419      |
# | train/             |          |
# |    actor_loss      | 30.4     |
# |    critic_loss     | 281      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 321      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.26     |
# |    ep_rew_mean     | -44.9    |
# | time/              |          |
# |    episodes        | 120      |
# |    fps             | 35       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 434      |
# | train/             |          |
# |    actor_loss      | 34.5     |
# |    critic_loss     | 263      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 335      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.23     |
# |    ep_rew_mean     | -44.2    |
# | time/              |          |
# |    episodes        | 124      |
# |    fps             | 35       |
# |    time_elapsed    | 12       |
# |    total_timesteps | 447      |
# | train/             |          |
# |    actor_loss      | 34.9     |
# |    critic_loss     | 195      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 349      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.23     |
# |    ep_rew_mean     | -43.8    |
# | time/              |          |
# |    episodes        | 128      |
# |    fps             | 35       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 459      |
# | train/             |          |
# |    actor_loss      | 35.4     |
# |    critic_loss     | 197      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 360      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.24     |
# |    ep_rew_mean     | -43.9    |
# | time/              |          |
# |    episodes        | 132      |
# |    fps             | 34       |
# |    time_elapsed    | 13       |
# |    total_timesteps | 474      |
# | train/             |          |
# |    actor_loss      | 35.1     |
# |    critic_loss     | 173      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 375      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.24     |
# |    ep_rew_mean     | -43.8    |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 34       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 487      |
# | train/             |          |
# |    actor_loss      | 35.6     |
# |    critic_loss     | 164      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 387      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.26     |
# |    ep_rew_mean     | -44      |
# | time/              |          |
# |    episodes        | 140      |
# |    fps             | 34       |
# |    time_elapsed    | 14       |
# |    total_timesteps | 500      |
# | train/             |          |
# |    actor_loss      | 33       |
# |    critic_loss     | 146      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 401      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.28     |
# |    ep_rew_mean     | -44.5    |
# | time/              |          |
# |    episodes        | 144      |
# |    fps             | 34       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 513      |
# | train/             |          |
# |    actor_loss      | 35.4     |
# |    critic_loss     | 171      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 412      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.31     |
# |    ep_rew_mean     | -45.7    |
# | time/              |          |
# |    episodes        | 148      |
# |    fps             | 33       |
# |    time_elapsed    | 15       |
# |    total_timesteps | 528      |
# | train/             |          |
# |    actor_loss      | 37.5     |
# |    critic_loss     | 110      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 428      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.32     |
# |    ep_rew_mean     | -45.3    |
# | time/              |          |
# |    episodes        | 152      |
# |    fps             | 33       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 542      |
# | train/             |          |
# |    actor_loss      | 36.2     |
# |    critic_loss     | 99.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 443      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.3      |
# |    ep_rew_mean     | -44.4    |
# | time/              |          |
# |    episodes        | 156      |
# |    fps             | 33       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 555      |
# | train/             |          |
# |    actor_loss      | 36       |
# |    critic_loss     | 76.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 457      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.28     |
# |    ep_rew_mean     | -43.1    |
# | time/              |          |
# |    episodes        | 160      |
# |    fps             | 33       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 569      |
# | train/             |          |
# |    actor_loss      | 37       |
# |    critic_loss     | 62.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 470      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.29     |
# |    ep_rew_mean     | -43.3    |
# | time/              |          |
# |    episodes        | 164      |
# |    fps             | 33       |
# |    time_elapsed    | 17       |
# |    total_timesteps | 581      |
# | train/             |          |
# |    actor_loss      | 36.1     |
# |    critic_loss     | 60.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 482      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.27     |
# |    ep_rew_mean     | -42.6    |
# | time/              |          |
# |    episodes        | 168      |
# |    fps             | 32       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 594      |
# | train/             |          |
# |    actor_loss      | 38.6     |
# |    critic_loss     | 51.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 494      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.26     |
# |    ep_rew_mean     | -42.5    |
# | time/              |          |
# |    episodes        | 172      |
# |    fps             | 32       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 606      |
# | train/             |          |
# |    actor_loss      | 36.7     |
# |    critic_loss     | 54.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 507      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.26     |
# |    ep_rew_mean     | -42.5    |
# | time/              |          |
# |    episodes        | 176      |
# |    fps             | 32       |
# |    time_elapsed    | 18       |
# |    total_timesteps | 619      |
# | train/             |          |
# |    actor_loss      | 37.1     |
# |    critic_loss     | 44.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 520      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.22     |
# |    ep_rew_mean     | -41.4    |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 32       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 629      |
# | train/             |          |
# |    actor_loss      | 39.5     |
# |    critic_loss     | 51.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 529      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.2      |
# |    ep_rew_mean     | -40.9    |
# | time/              |          |
# |    episodes        | 184      |
# |    fps             | 32       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 640      |
# | train/             |          |
# |    actor_loss      | 38.5     |
# |    critic_loss     | 47.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 540      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.22     |
# |    ep_rew_mean     | -41.8    |
# | time/              |          |
# |    episodes        | 188      |
# |    fps             | 32       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 655      |
# | train/             |          |
# |    actor_loss      | 38.4     |
# |    critic_loss     | 42.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 555      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.19     |
# |    ep_rew_mean     | -41      |
# | time/              |          |
# |    episodes        | 192      |
# |    fps             | 32       |
# |    time_elapsed    | 20       |
# |    total_timesteps | 668      |
# | train/             |          |
# |    actor_loss      | 37.3     |
# |    critic_loss     | 41.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 568      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.19     |
# |    ep_rew_mean     | -40.9    |
# | time/              |          |
# |    episodes        | 196      |
# |    fps             | 32       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 680      |
# | train/             |          |
# |    actor_loss      | 39.2     |
# |    critic_loss     | 29.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 581      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.19     |
# |    ep_rew_mean     | -41      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 32       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 691      |
# | train/             |          |
# |    actor_loss      | 38.2     |
# |    critic_loss     | 24.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 591      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.21     |
# |    ep_rew_mean     | -41.4    |
# | time/              |          |
# |    episodes        | 204      |
# |    fps             | 31       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 703      |
# | train/             |          |
# |    actor_loss      | 38.3     |
# |    critic_loss     | 27.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 604      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.19     |
# |    ep_rew_mean     | -40.5    |
# | time/              |          |
# |    episodes        | 208      |
# |    fps             | 31       |
# |    time_elapsed    | 22       |
# |    total_timesteps | 715      |
# | train/             |          |
# |    actor_loss      | 35.1     |
# |    critic_loss     | 24.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 616      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.16     |
# |    ep_rew_mean     | -39.9    |
# | time/              |          |
# |    episodes        | 212      |
# |    fps             | 31       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 725      |
# | train/             |          |
# |    actor_loss      | 38.1     |
# |    critic_loss     | 29.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 627      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.21     |
# |    ep_rew_mean     | -41.2    |
# | time/              |          |
# |    episodes        | 216      |
# |    fps             | 31       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 740      |
# | train/             |          |
# |    actor_loss      | 35.8     |
# |    critic_loss     | 26.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 642      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.17     |
# |    ep_rew_mean     | -40      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 31       |
# |    time_elapsed    | 23       |
# |    total_timesteps | 751      |
# | train/             |          |
# |    actor_loss      | 39.9     |
# |    critic_loss     | 22.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 652      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.16     |
# |    ep_rew_mean     | -39.5    |
# | time/              |          |
# |    episodes        | 224      |
# |    fps             | 31       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 763      |
# | train/             |          |
# |    actor_loss      | 37.9     |
# |    critic_loss     | 30.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 664      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.17     |
# |    ep_rew_mean     | -40.2    |
# | time/              |          |
# |    episodes        | 228      |
# |    fps             | 31       |
# |    time_elapsed    | 24       |
# |    total_timesteps | 776      |
# | train/             |          |
# |    actor_loss      | 35.7     |
# |    critic_loss     | 25.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 677      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.13     |
# |    ep_rew_mean     | -39.3    |
# | time/              |          |
# |    episodes        | 232      |
# |    fps             | 31       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 787      |
# | train/             |          |
# |    actor_loss      | 39       |
# |    critic_loss     | 42.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 688      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.15     |
# |    ep_rew_mean     | -40.2    |
# | time/              |          |
# |    episodes        | 236      |
# |    fps             | 31       |
# |    time_elapsed    | 25       |
# |    total_timesteps | 802      |
# | train/             |          |
# |    actor_loss      | 36.8     |
# |    critic_loss     | 29.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 702      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.12     |
# |    ep_rew_mean     | -39.5    |
# | time/              |          |
# |    episodes        | 240      |
# |    fps             | 30       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 812      |
# | train/             |          |
# |    actor_loss      | 33.2     |
# |    critic_loss     | 30.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 713      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.15     |
# |    ep_rew_mean     | -40.4    |
# | time/              |          |
# |    episodes        | 244      |
# |    fps             | 30       |
# |    time_elapsed    | 26       |
# |    total_timesteps | 828      |
# | train/             |          |
# |    actor_loss      | 35.3     |
# |    critic_loss     | 24.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 728      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.15     |
# |    ep_rew_mean     | -39.9    |
# | time/              |          |
# |    episodes        | 248      |
# |    fps             | 30       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 843      |
# | train/             |          |
# |    actor_loss      | 34.5     |
# |    critic_loss     | 24.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 744      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.13     |
# |    ep_rew_mean     | -40      |
# | time/              |          |
# |    episodes        | 252      |
# |    fps             | 30       |
# |    time_elapsed    | 27       |
# |    total_timesteps | 855      |
# | train/             |          |
# |    actor_loss      | 31.1     |
# |    critic_loss     | 15.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 756      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.13     |
# |    ep_rew_mean     | -40.1    |
# | time/              |          |
# |    episodes        | 256      |
# |    fps             | 30       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 868      |
# | train/             |          |
# |    actor_loss      | 36.9     |
# |    critic_loss     | 17.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 769      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.12     |
# |    ep_rew_mean     | -40.4    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 30       |
# |    time_elapsed    | 28       |
# |    total_timesteps | 881      |
# | train/             |          |
# |    actor_loss      | 33.7     |
# |    critic_loss     | 23.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 783      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.13     |
# |    ep_rew_mean     | -40.7    |
# | time/              |          |
# |    episodes        | 264      |
# |    fps             | 30       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 894      |
# | train/             |          |
# |    actor_loss      | 35.9     |
# |    critic_loss     | 21.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 796      |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 3.12     |
# |    ep_rew_mean     | -40.6    |
# | time/              |          |
# |    episodes        | 268      |
# |    fps             | 30       |
# |    time_elapsed    | 29       |
# |    total_timesteps | 906      |
# | train/             |          |
# |    actor_loss      | 35.3     |
# |    critic_loss     | 21.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 806      |
# ---------------------------------

# %%
model.learn(total_timesteps=100000)
# Out:
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.74e+03 |
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 2525      |
# |    time_elapsed    | 0         |
# |    total_timesteps | 96        |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.25e+03 |
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 225       |
# |    time_elapsed    | 0         |
# |    total_timesteps | 192       |
# | train/             |           |
# |    actor_loss      | 635       |
# |    critic_loss     | 1.13e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 9984      |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.26e+03 |
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 154       |
# |    time_elapsed    | 1         |
# |    total_timesteps | 288       |
# | train/             |           |
# |    actor_loss      | 636       |
# |    critic_loss     | 1.14e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10080     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.28e+03 |
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 129       |
# |    time_elapsed    | 2         |
# |    total_timesteps | 384       |
# | train/             |           |
# |    actor_loss      | 645       |
# |    critic_loss     | 1.04e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10176     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 120      |
# |    time_elapsed    | 3        |
# |    total_timesteps | 480      |
# | train/             |          |
# |    actor_loss      | 637      |
# |    critic_loss     | 1.06e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10272    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 115       |
# |    time_elapsed    | 4         |
# |    total_timesteps | 576       |
# | train/             |           |
# |    actor_loss      | 640       |
# |    critic_loss     | 1.07e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10368     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 28        |
# |    fps             | 111       |
# |    time_elapsed    | 6         |
# |    total_timesteps | 672       |
# | train/             |           |
# |    actor_loss      | 639       |
# |    critic_loss     | 1.04e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10464     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 32        |
# |    fps             | 108       |
# |    time_elapsed    | 7         |
# |    total_timesteps | 768       |
# | train/             |           |
# |    actor_loss      | 631       |
# |    critic_loss     | 908       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10560     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 36        |
# |    fps             | 107       |
# |    time_elapsed    | 8         |
# |    total_timesteps | 864       |
# | train/             |           |
# |    actor_loss      | 644       |
# |    critic_loss     | 944       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10656     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 105       |
# |    time_elapsed    | 9         |
# |    total_timesteps | 960       |
# | train/             |           |
# |    actor_loss      | 652       |
# |    critic_loss     | 898       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10752     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 44        |
# |    fps             | 104       |
# |    time_elapsed    | 10        |
# |    total_timesteps | 1056      |
# | train/             |           |
# |    actor_loss      | 640       |
# |    critic_loss     | 1.18e+03  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10848     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 48        |
# |    fps             | 102       |
# |    time_elapsed    | 11        |
# |    total_timesteps | 1152      |
# | train/             |           |
# |    actor_loss      | 639       |
# |    critic_loss     | 974       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 10944     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 52        |
# |    fps             | 101       |
# |    time_elapsed    | 12        |
# |    total_timesteps | 1248      |
# | train/             |           |
# |    actor_loss      | 642       |
# |    critic_loss     | 928       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11040     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 56        |
# |    fps             | 101       |
# |    time_elapsed    | 13        |
# |    total_timesteps | 1344      |
# | train/             |           |
# |    actor_loss      | 652       |
# |    critic_loss     | 982       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11136     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 100       |
# |    time_elapsed    | 14        |
# |    total_timesteps | 1440      |
# | train/             |           |
# |    actor_loss      | 651       |
# |    critic_loss     | 953       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11232     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 64        |
# |    fps             | 100       |
# |    time_elapsed    | 15        |
# |    total_timesteps | 1536      |
# | train/             |           |
# |    actor_loss      | 658       |
# |    critic_loss     | 856       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11328     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 68        |
# |    fps             | 99        |
# |    time_elapsed    | 16        |
# |    total_timesteps | 1632      |
# | train/             |           |
# |    actor_loss      | 663       |
# |    critic_loss     | 838       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11424     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 72        |
# |    fps             | 99        |
# |    time_elapsed    | 17        |
# |    total_timesteps | 1728      |
# | train/             |           |
# |    actor_loss      | 663       |
# |    critic_loss     | 816       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11520     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 76        |
# |    fps             | 99        |
# |    time_elapsed    | 18        |
# |    total_timesteps | 1824      |
# | train/             |           |
# |    actor_loss      | 662       |
# |    critic_loss     | 883       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11616     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 99        |
# |    time_elapsed    | 19        |
# |    total_timesteps | 1920      |
# | train/             |           |
# |    actor_loss      | 656       |
# |    critic_loss     | 884       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11712     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 84        |
# |    fps             | 99        |
# |    time_elapsed    | 20        |
# |    total_timesteps | 2016      |
# | train/             |           |
# |    actor_loss      | 648       |
# |    critic_loss     | 801       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11808     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 88        |
# |    fps             | 99        |
# |    time_elapsed    | 21        |
# |    total_timesteps | 2112      |
# | train/             |           |
# |    actor_loss      | 665       |
# |    critic_loss     | 808       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 11904     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 92        |
# |    fps             | 99        |
# |    time_elapsed    | 22        |
# |    total_timesteps | 2208      |
# | train/             |           |
# |    actor_loss      | 657       |
# |    critic_loss     | 806       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12000     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 96        |
# |    fps             | 98        |
# |    time_elapsed    | 23        |
# |    total_timesteps | 2304      |
# | train/             |           |
# |    actor_loss      | 663       |
# |    critic_loss     | 686       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12096     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 98        |
# |    time_elapsed    | 24        |
# |    total_timesteps | 2400      |
# | train/             |           |
# |    actor_loss      | 656       |
# |    critic_loss     | 682       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12192     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 104       |
# |    fps             | 98        |
# |    time_elapsed    | 25        |
# |    total_timesteps | 2496      |
# | train/             |           |
# |    actor_loss      | 659       |
# |    critic_loss     | 902       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12288     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 108       |
# |    fps             | 98        |
# |    time_elapsed    | 26        |
# |    total_timesteps | 2592      |
# | train/             |           |
# |    actor_loss      | 657       |
# |    critic_loss     | 680       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12384     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 112       |
# |    fps             | 98        |
# |    time_elapsed    | 27        |
# |    total_timesteps | 2688      |
# | train/             |           |
# |    actor_loss      | 672       |
# |    critic_loss     | 936       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12480     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 116       |
# |    fps             | 98        |
# |    time_elapsed    | 28        |
# |    total_timesteps | 2784      |
# | train/             |           |
# |    actor_loss      | 664       |
# |    critic_loss     | 674       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12576     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 98        |
# |    time_elapsed    | 29        |
# |    total_timesteps | 2880      |
# | train/             |           |
# |    actor_loss      | 667       |
# |    critic_loss     | 650       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12672     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 124       |
# |    fps             | 98        |
# |    time_elapsed    | 30        |
# |    total_timesteps | 2976      |
# | train/             |           |
# |    actor_loss      | 666       |
# |    critic_loss     | 678       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12768     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 128       |
# |    fps             | 97        |
# |    time_elapsed    | 31        |
# |    total_timesteps | 3072      |
# | train/             |           |
# |    actor_loss      | 666       |
# |    critic_loss     | 675       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12864     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 132       |
# |    fps             | 97        |
# |    time_elapsed    | 32        |
# |    total_timesteps | 3168      |
# | train/             |           |
# |    actor_loss      | 685       |
# |    critic_loss     | 853       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 12960     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    episodes        | 136      |
# |    fps             | 97       |
# |    time_elapsed    | 33       |
# |    total_timesteps | 3264     |
# | train/             |          |
# |    actor_loss      | 662      |
# |    critic_loss     | 701      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 13056    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 97        |
# |    time_elapsed    | 34        |
# |    total_timesteps | 3360      |
# | train/             |           |
# |    actor_loss      | 666       |
# |    critic_loss     | 921       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13152     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 144       |
# |    fps             | 97        |
# |    time_elapsed    | 35        |
# |    total_timesteps | 3456      |
# | train/             |           |
# |    actor_loss      | 661       |
# |    critic_loss     | 698       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13248     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 148       |
# |    fps             | 97        |
# |    time_elapsed    | 36        |
# |    total_timesteps | 3552      |
# | train/             |           |
# |    actor_loss      | 673       |
# |    critic_loss     | 618       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13344     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 152       |
# |    fps             | 97        |
# |    time_elapsed    | 37        |
# |    total_timesteps | 3648      |
# | train/             |           |
# |    actor_loss      | 667       |
# |    critic_loss     | 648       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13440     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 156       |
# |    fps             | 97        |
# |    time_elapsed    | 38        |
# |    total_timesteps | 3744      |
# | train/             |           |
# |    actor_loss      | 661       |
# |    critic_loss     | 678       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13536     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 97        |
# |    time_elapsed    | 39        |
# |    total_timesteps | 3840      |
# | train/             |           |
# |    actor_loss      | 677       |
# |    critic_loss     | 601       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13632     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 164       |
# |    fps             | 97        |
# |    time_elapsed    | 40        |
# |    total_timesteps | 3936      |
# | train/             |           |
# |    actor_loss      | 675       |
# |    critic_loss     | 731       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13728     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 168       |
# |    fps             | 97        |
# |    time_elapsed    | 41        |
# |    total_timesteps | 4032      |
# | train/             |           |
# |    actor_loss      | 678       |
# |    critic_loss     | 747       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13824     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 172       |
# |    fps             | 97        |
# |    time_elapsed    | 42        |
# |    total_timesteps | 4128      |
# | train/             |           |
# |    actor_loss      | 668       |
# |    critic_loss     | 627       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 13920     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 176       |
# |    fps             | 97        |
# |    time_elapsed    | 43        |
# |    total_timesteps | 4224      |
# | train/             |           |
# |    actor_loss      | 672       |
# |    critic_loss     | 681       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14016     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 96        |
# |    time_elapsed    | 44        |
# |    total_timesteps | 4320      |
# | train/             |           |
# |    actor_loss      | 671       |
# |    critic_loss     | 604       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14112     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 184       |
# |    fps             | 96        |
# |    time_elapsed    | 45        |
# |    total_timesteps | 4416      |
# | train/             |           |
# |    actor_loss      | 672       |
# |    critic_loss     | 514       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14208     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 188       |
# |    fps             | 96        |
# |    time_elapsed    | 46        |
# |    total_timesteps | 4512      |
# | train/             |           |
# |    actor_loss      | 674       |
# |    critic_loss     | 593       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14304     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 192       |
# |    fps             | 96        |
# |    time_elapsed    | 47        |
# |    total_timesteps | 4608      |
# | train/             |           |
# |    actor_loss      | 656       |
# |    critic_loss     | 605       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14400     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 196       |
# |    fps             | 96        |
# |    time_elapsed    | 48        |
# |    total_timesteps | 4704      |
# | train/             |           |
# |    actor_loss      | 671       |
# |    critic_loss     | 610       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14496     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 96        |
# |    time_elapsed    | 49        |
# |    total_timesteps | 4800      |
# | train/             |           |
# |    actor_loss      | 672       |
# |    critic_loss     | 690       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14592     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 204       |
# |    fps             | 95        |
# |    time_elapsed    | 51        |
# |    total_timesteps | 4896      |
# | train/             |           |
# |    actor_loss      | 660       |
# |    critic_loss     | 599       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14688     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 208       |
# |    fps             | 95        |
# |    time_elapsed    | 52        |
# |    total_timesteps | 4992      |
# | train/             |           |
# |    actor_loss      | 664       |
# |    critic_loss     | 536       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14784     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 212       |
# |    fps             | 95        |
# |    time_elapsed    | 53        |
# |    total_timesteps | 5088      |
# | train/             |           |
# |    actor_loss      | 667       |
# |    critic_loss     | 600       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14880     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 216       |
# |    fps             | 95        |
# |    time_elapsed    | 54        |
# |    total_timesteps | 5184      |
# | train/             |           |
# |    actor_loss      | 664       |
# |    critic_loss     | 629       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 14976     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 95        |
# |    time_elapsed    | 55        |
# |    total_timesteps | 5280      |
# | train/             |           |
# |    actor_loss      | 684       |
# |    critic_loss     | 490       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15072     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 224       |
# |    fps             | 95        |
# |    time_elapsed    | 56        |
# |    total_timesteps | 5376      |
# | train/             |           |
# |    actor_loss      | 664       |
# |    critic_loss     | 484       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15168     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 228       |
# |    fps             | 95        |
# |    time_elapsed    | 57        |
# |    total_timesteps | 5472      |
# | train/             |           |
# |    actor_loss      | 676       |
# |    critic_loss     | 811       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15264     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 232       |
# |    fps             | 95        |
# |    time_elapsed    | 58        |
# |    total_timesteps | 5568      |
# | train/             |           |
# |    actor_loss      | 684       |
# |    critic_loss     | 524       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15360     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 236       |
# |    fps             | 95        |
# |    time_elapsed    | 59        |
# |    total_timesteps | 5664      |
# | train/             |           |
# |    actor_loss      | 684       |
# |    critic_loss     | 535       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15456     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 95        |
# |    time_elapsed    | 60        |
# |    total_timesteps | 5760      |
# | train/             |           |
# |    actor_loss      | 675       |
# |    critic_loss     | 676       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15552     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 244       |
# |    fps             | 94        |
# |    time_elapsed    | 61        |
# |    total_timesteps | 5856      |
# | train/             |           |
# |    actor_loss      | 670       |
# |    critic_loss     | 422       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15648     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 248       |
# |    fps             | 94        |
# |    time_elapsed    | 62        |
# |    total_timesteps | 5952      |
# | train/             |           |
# |    actor_loss      | 678       |
# |    critic_loss     | 503       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15744     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 252       |
# |    fps             | 94        |
# |    time_elapsed    | 64        |
# |    total_timesteps | 6048      |
# | train/             |           |
# |    actor_loss      | 670       |
# |    critic_loss     | 469       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15840     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 256       |
# |    fps             | 94        |
# |    time_elapsed    | 65        |
# |    total_timesteps | 6144      |
# | train/             |           |
# |    actor_loss      | 673       |
# |    critic_loss     | 506       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15936     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 94        |
# |    time_elapsed    | 66        |
# |    total_timesteps | 6240      |
# | train/             |           |
# |    actor_loss      | 681       |
# |    critic_loss     | 446       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16032     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 264       |
# |    fps             | 94        |
# |    time_elapsed    | 67        |
# |    total_timesteps | 6336      |
# | train/             |           |
# |    actor_loss      | 674       |
# |    critic_loss     | 531       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16128     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 268       |
# |    fps             | 94        |
# |    time_elapsed    | 68        |
# |    total_timesteps | 6432      |
# | train/             |           |
# |    actor_loss      | 676       |
# |    critic_loss     | 580       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16224     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 272       |
# |    fps             | 93        |
# |    time_elapsed    | 69        |
# |    total_timesteps | 6528      |
# | train/             |           |
# |    actor_loss      | 675       |
# |    critic_loss     | 457       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16320     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 276       |
# |    fps             | 93        |
# |    time_elapsed    | 70        |
# |    total_timesteps | 6624      |
# | train/             |           |
# |    actor_loss      | 677       |
# |    critic_loss     | 451       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16416     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 93        |
# |    time_elapsed    | 71        |
# |    total_timesteps | 6720      |
# | train/             |           |
# |    actor_loss      | 665       |
# |    critic_loss     | 478       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16512     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 284       |
# |    fps             | 93        |
# |    time_elapsed    | 72        |
# |    total_timesteps | 6816      |
# | train/             |           |
# |    actor_loss      | 678       |
# |    critic_loss     | 418       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16608     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 288       |
# |    fps             | 93        |
# |    time_elapsed    | 73        |
# |    total_timesteps | 6912      |
# | train/             |           |
# |    actor_loss      | 684       |
# |    critic_loss     | 448       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16704     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    episodes        | 292       |
# |    fps             | 93        |
# |    time_elapsed    | 74        |
# |    total_timesteps | 7008      |
# | train/             |           |
# |    actor_loss      | 672       |
# |    critic_loss     | 519       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16800     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 296       |
# |    fps             | 93        |
# |    time_elapsed    | 75        |
# |    total_timesteps | 7104      |
# | train/             |           |
# |    actor_loss      | 686       |
# |    critic_loss     | 486       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16896     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.18e+03 |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 93        |
# |    time_elapsed    | 76        |
# |    total_timesteps | 7200      |
# | train/             |           |
# |    actor_loss      | 682       |
# |    critic_loss     | 498       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 16992     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24       |
# |    ep_rew_mean     | -1.2e+03 |
# | time/              |          |
# |    episodes        | 304      |
# |    fps             | 93       |
# |    time_elapsed    | 77       |
# |    total_timesteps | 7296     |
# | train/             |          |
# |    actor_loss      | 672      |
# |    critic_loss     | 427      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 17088    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.21e+03 |
# | time/              |           |
# |    episodes        | 308       |
# |    fps             | 93        |
# |    time_elapsed    | 79        |
# |    total_timesteps | 7392      |
# | train/             |           |
# |    actor_loss      | 680       |
# |    critic_loss     | 506       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17184     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.21e+03 |
# | time/              |           |
# |    episodes        | 312       |
# |    fps             | 93        |
# |    time_elapsed    | 80        |
# |    total_timesteps | 7488      |
# | train/             |           |
# |    actor_loss      | 681       |
# |    critic_loss     | 464       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17280     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.21e+03 |
# | time/              |           |
# |    episodes        | 316       |
# |    fps             | 93        |
# |    time_elapsed    | 81        |
# |    total_timesteps | 7584      |
# | train/             |           |
# |    actor_loss      | 667       |
# |    critic_loss     | 425       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17376     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.21e+03 |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 93        |
# |    time_elapsed    | 82        |
# |    total_timesteps | 7680      |
# | train/             |           |
# |    actor_loss      | 667       |
# |    critic_loss     | 409       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17472     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    episodes        | 324       |
# |    fps             | 93        |
# |    time_elapsed    | 83        |
# |    total_timesteps | 7776      |
# | train/             |           |
# |    actor_loss      | 666       |
# |    critic_loss     | 382       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17568     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.19e+03 |
# | time/              |           |
# |    episodes        | 328       |
# |    fps             | 93        |
# |    time_elapsed    | 84        |
# |    total_timesteps | 7872      |
# | train/             |           |
# |    actor_loss      | 665       |
# |    critic_loss     | 464       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17664     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 332       |
# |    fps             | 93        |
# |    time_elapsed    | 85        |
# |    total_timesteps | 7968      |
# | train/             |           |
# |    actor_loss      | 672       |
# |    critic_loss     | 513       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17760     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 336       |
# |    fps             | 93        |
# |    time_elapsed    | 86        |
# |    total_timesteps | 8064      |
# | train/             |           |
# |    actor_loss      | 683       |
# |    critic_loss     | 397       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17856     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.17e+03 |
# | time/              |           |
# |    episodes        | 340       |
# |    fps             | 93        |
# |    time_elapsed    | 87        |
# |    total_timesteps | 8160      |
# | train/             |           |
# |    actor_loss      | 681       |
# |    critic_loss     | 415       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 17952     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 344       |
# |    fps             | 93        |
# |    time_elapsed    | 88        |
# |    total_timesteps | 8256      |
# | train/             |           |
# |    actor_loss      | 665       |
# |    critic_loss     | 390       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18048     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 348       |
# |    fps             | 93        |
# |    time_elapsed    | 89        |
# |    total_timesteps | 8352      |
# | train/             |           |
# |    actor_loss      | 685       |
# |    critic_loss     | 435       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18144     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 352       |
# |    fps             | 93        |
# |    time_elapsed    | 90        |
# |    total_timesteps | 8448      |
# | train/             |           |
# |    actor_loss      | 685       |
# |    critic_loss     | 417       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18240     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 356       |
# |    fps             | 93        |
# |    time_elapsed    | 91        |
# |    total_timesteps | 8544      |
# | train/             |           |
# |    actor_loss      | 680       |
# |    critic_loss     | 360       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18336     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 360       |
# |    fps             | 93        |
# |    time_elapsed    | 92        |
# |    total_timesteps | 8640      |
# | train/             |           |
# |    actor_loss      | 670       |
# |    critic_loss     | 342       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18432     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 364       |
# |    fps             | 93        |
# |    time_elapsed    | 93        |
# |    total_timesteps | 8736      |
# | train/             |           |
# |    actor_loss      | 690       |
# |    critic_loss     | 372       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18528     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.15e+03 |
# | time/              |           |
# |    episodes        | 368       |
# |    fps             | 93        |
# |    time_elapsed    | 94        |
# |    total_timesteps | 8832      |
# | train/             |           |
# |    actor_loss      | 687       |
# |    critic_loss     | 430       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18624     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 372       |
# |    fps             | 93        |
# |    time_elapsed    | 95        |
# |    total_timesteps | 8928      |
# | train/             |           |
# |    actor_loss      | 693       |
# |    critic_loss     | 364       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18720     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 376       |
# |    fps             | 93        |
# |    time_elapsed    | 96        |
# |    total_timesteps | 9024      |
# | train/             |           |
# |    actor_loss      | 693       |
# |    critic_loss     | 399       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18816     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 380       |
# |    fps             | 93        |
# |    time_elapsed    | 97        |
# |    total_timesteps | 9120      |
# | train/             |           |
# |    actor_loss      | 671       |
# |    critic_loss     | 358       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 18912     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 384       |
# |    fps             | 93        |
# |    time_elapsed    | 98        |
# |    total_timesteps | 9216      |
# | train/             |           |
# |    actor_loss      | 682       |
# |    critic_loss     | 438       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19008     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 388       |
# |    fps             | 93        |
# |    time_elapsed    | 99        |
# |    total_timesteps | 9312      |
# | train/             |           |
# |    actor_loss      | 689       |
# |    critic_loss     | 344       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19104     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 392       |
# |    fps             | 93        |
# |    time_elapsed    | 100       |
# |    total_timesteps | 9408      |
# | train/             |           |
# |    actor_loss      | 674       |
# |    critic_loss     | 355       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19200     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 396       |
# |    fps             | 93        |
# |    time_elapsed    | 101       |
# |    total_timesteps | 9504      |
# | train/             |           |
# |    actor_loss      | 676       |
# |    critic_loss     | 347       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19296     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.16e+03 |
# | time/              |           |
# |    episodes        | 400       |
# |    fps             | 93        |
# |    time_elapsed    | 102       |
# |    total_timesteps | 9600      |
# | train/             |           |
# |    actor_loss      | 680       |
# |    critic_loss     | 349       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19392     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 404       |
# |    fps             | 93        |
# |    time_elapsed    | 103       |
# |    total_timesteps | 9696      |
# | train/             |           |
# |    actor_loss      | 661       |
# |    critic_loss     | 306       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19488     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 24        |
# |    ep_rew_mean     | -1.14e+03 |
# | time/              |           |
# |    episodes        | 408       |
# |    fps             | 93        |
# |    time_elapsed    | 105       |
# |    total_timesteps | 9792      |
# | train/             |           |
# |    actor_loss      | 683       |
# |    critic_loss     | 408       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 19584     |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 model.learn(total_timesteps=10000)
#
# File ~/miniconda/envs/mlEnv/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:222, in TD3.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     213 def learn(
#     214     self: SelfTD3,
#     215     total_timesteps: int,
#    (...)
#     220     progress_bar: bool = False,
#     221 ) -> SelfTD3:
# --> 222     return super().learn(
#     223         total_timesteps=total_timesteps,
#     224         callback=callback,
#     225         log_interval=log_interval,
#     226         tb_log_name=tb_log_name,
#     227         reset_num_timesteps=reset_num_timesteps,
#     228         progress_bar=progress_bar,
#     229     )
#
# File ~/miniconda/envs/mlEnv/lib/python3.10/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     345         # Special case when the user passes `gradient_steps=0`
#     346         if gradient_steps > 0:
# --> 347             self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     349 callback.on_training_end()
#     351 return self
#
# File ~/miniconda/envs/mlEnv/lib/python3.10/site-packages/stable_baselines3/td3/td3.py:188, in TD3.train(self, gradient_steps, batch_size)
#     186 # Optimize the critics
#     187 self.critic.optimizer.zero_grad()
# --> 188 critic_loss.backward()
#     189 self.critic.optimizer.step()
#     191 # Delayed policy updates
#
# File ~/miniconda/envs/mlEnv/lib/python3.10/site-packages/torch/_tensor.py:522, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     512 if has_torch_function_unary(self):
#     513     return handle_torch_function(
#     514         Tensor.backward,
#     515         (self,),
#    (...)
#     520         inputs=inputs,
#     521     )
# --> 522 torch.autograd.backward(
#     523     self, gradient, retain_graph, create_graph, inputs=inputs
#     524 )
#
# File ~/miniconda/envs/mlEnv/lib/python3.10/site-packages/torch/autograd/__init__.py:266, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     261     retain_graph = create_graph
#     263 # The reason we repeat the same comment below is that
#     264 # some Python versions print out the first line of a multi-line function
#     265 # calls in the traceback and some print out the last line
# --> 266 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     267     tensors,
#     268     grad_tensors_,
#     269     retain_graph,
#     270     create_graph,
#     271     inputs,
#     272     allow_unreachable=True,
#     273     accumulate_grad=True,
#     274 )
#
# KeyboardInterrupt:

# %%
obs, reward, done,trunc, _ = env.step([9])  # Unpack and use only the observation for the next predict call
env.render()
# Out:
# Time: 1.0, Battery Level: 44.00 %, Price: $0.111 per kWh

# %%
obs, _ = env.reset()  # Unpack to get only the observation
for _ in range(100):
    action, _states = model.predict(obs, deterministic=True)
    print(f'Charge at {action[0]} kwh')
    obs, reward, done,trunc, _ = env.step(action)  # Unpack and use only the observation for the next predict call
    env.render()
    print(f'Reward {reward}')
    if done:
        obs, _ = env.reset()  # Reset the environment and unpack the observation
# Out:
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 36.00 %, Price: $0.111 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 36.00 %, Price: $0.111 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 36.00 %, Price: $0.111 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 36.00 %, Price: $0.111 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 5.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 6.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 7.0, Battery Level: 36.00 %, Price: $0.109 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 8.0, Battery Level: 36.00 %, Price: $0.111 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 9.0, Battery Level: 36.00 %, Price: $0.111 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 10.0, Battery Level: 36.00 %, Price: $0.111 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 11.0, Battery Level: 36.00 %, Price: $0.111 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 12.0, Battery Level: 36.00 %, Price: $0.109 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 13.0, Battery Level: 36.00 %, Price: $0.109 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 14.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 15.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 16.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 17.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 18.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 19.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 20.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 21.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 22.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 23.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -59.0
# Charge at 0.0 kwh
# Time: 24.0, Battery Level: 36.00 %, Price: $0.143 per kWh
# Reward -359.0
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 43.00 %, Price: $0.111 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 43.00 %, Price: $0.111 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 43.00 %, Price: $0.111 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 43.00 %, Price: $0.111 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 5.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 6.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 7.0, Battery Level: 43.00 %, Price: $0.109 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 8.0, Battery Level: 43.00 %, Price: $0.111 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 9.0, Battery Level: 43.00 %, Price: $0.111 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 10.0, Battery Level: 43.00 %, Price: $0.111 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 11.0, Battery Level: 43.00 %, Price: $0.111 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 12.0, Battery Level: 43.00 %, Price: $0.109 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 13.0, Battery Level: 43.00 %, Price: $0.109 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 14.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 15.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 16.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 17.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 18.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 19.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 20.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 21.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 22.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 23.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -52.0
# Charge at 0.0 kwh
# Time: 24.0, Battery Level: 43.00 %, Price: $0.143 per kWh
# Reward -352.0
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 57.00 %, Price: $0.111 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 57.00 %, Price: $0.111 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 57.00 %, Price: $0.111 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 57.00 %, Price: $0.111 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 5.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 6.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 7.0, Battery Level: 57.00 %, Price: $0.109 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 8.0, Battery Level: 57.00 %, Price: $0.111 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 9.0, Battery Level: 57.00 %, Price: $0.111 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 10.0, Battery Level: 57.00 %, Price: $0.111 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 11.0, Battery Level: 57.00 %, Price: $0.111 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 12.0, Battery Level: 57.00 %, Price: $0.109 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 13.0, Battery Level: 57.00 %, Price: $0.109 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 14.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 15.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 16.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 17.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 18.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 19.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 20.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 21.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 22.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 23.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -38.0
# Charge at 0.0 kwh
# Time: 24.0, Battery Level: 57.00 %, Price: $0.143 per kWh
# Reward -338.0
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 71.00 %, Price: $0.111 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 71.00 %, Price: $0.111 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 71.00 %, Price: $0.111 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 71.00 %, Price: $0.111 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 5.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 6.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 7.0, Battery Level: 71.00 %, Price: $0.109 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 8.0, Battery Level: 71.00 %, Price: $0.111 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 9.0, Battery Level: 71.00 %, Price: $0.111 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 10.0, Battery Level: 71.00 %, Price: $0.111 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 11.0, Battery Level: 71.00 %, Price: $0.111 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 12.0, Battery Level: 71.00 %, Price: $0.109 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 13.0, Battery Level: 71.00 %, Price: $0.109 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 14.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 15.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 16.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 17.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 18.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 19.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 20.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 21.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 22.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 23.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -24.0
# Charge at 0.0 kwh
# Time: 24.0, Battery Level: 71.00 %, Price: $0.143 per kWh
# Reward -324.0
# Charge at 0.0 kwh
# Time: 1.0, Battery Level: 47.00 %, Price: $0.111 per kWh
# Reward -48.0
# Charge at 0.0 kwh
# Time: 2.0, Battery Level: 47.00 %, Price: $0.111 per kWh
# Reward -48.0
# Charge at 0.0 kwh
# Time: 3.0, Battery Level: 47.00 %, Price: $0.111 per kWh
# Reward -48.0
# Charge at 0.0 kwh
# Time: 4.0, Battery Level: 47.00 %, Price: $0.111 per kWh
# Reward -48.0
