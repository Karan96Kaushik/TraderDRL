# %%
import pandas as pd
import talib

import glob

# %%
def create_df_from_file(file_name):
    print(file_name)
    df = pd.read_csv(file_name)

    df['time'] = pd.to_datetime(df['time'], unit='ms')

    # Apply Min-Max scaling to the selected columns
    columns_to_normalize = df.columns.difference(['time'])
    df = df.copy()  # Create a copy to preserve the original DataFrame
    df[columns_to_normalize] = (df[columns_to_normalize]) / (df[columns_to_normalize].iloc[0])

    # Calculate Moving Averages
    df['SMA_10'] = talib.SMA(df['close'], timeperiod=10)  # Simple Moving Average for 10 periods
    df['EMA_10'] = talib.EMA(df['close'], timeperiod=10)  # Exponential Moving Average for 10 periods
    df['SMA_day'] = talib.SMA(df['close'], timeperiod=6*60)  # Simple Moving Average for day periods
    df['EMA_day'] = talib.EMA(df['close'], timeperiod=6*60)  # Exponential Moving Average dayr 10 periods


    # Calculate RSI (Relative Strength Index)
    df['RSI_14'] = talib.RSI(df['close'], timeperiod=14)  # RSI over 14 periods

    # Calculate MACD (Moving Average Convergence Divergence)
    df['MACD'], df['MACD_signal'], df['MACD_hist'] = talib.MACD(df['close'], fastperiod=12, slowperiod=26, signalperiod=9)
    df = df.dropna()

    # Select columns to normalize (all except 'time')

    # Display the first few rows of the DataFrame with columns (except 'time')
    df = df
    # print(df)
    # Display the first few rows of the DataFrame
    return df

# %%
# Use glob to find all files matching the pattern 'Records*.csv'
file_list = glob.glob('Records/*.csv')

# Initialize an empty list to store dataframes
dfs = []
# print(file_list)
# Loop over the list of file names
for file_name in file_list:
    dfs.append(create_df_from_file(file_name))
# Out:
# Records/Records-ABCAPITAL-1677748500000-1709383680000.csv
# Records/Records-CONCOR-1677748500000-1709383560000.csv
# Records/Records-PEL-1677748500000-1709383500000.csv
# Records/Records-PETRONET-1677748500000-1709383740000.csv
# Records/Records-DEEPAKNTR-1677748500000-1709383620000.csv
# Records/Records-LODHA-1677748500000-1709383740000.csv
# Records/Records-IDEA-1677748500000-1709383740000.csv
# Records/Records-MAZDOCK-1677748500000-1709383680000.csv
# Records/Records-IRFC-1677748500000-1709383740000.csv
# Records/Records-LUPIN-1677748500000-1709383620000.csv
# Records/Records-TATACOMM-1677748500000-1709383680000.csv
# Records/Records-NAVINFLUOR-1677748500000-1709383500000.csv
# Records/Records-TIINDIA-1677748500000-1709383740000.csv
# Records/Records-ACC-1677748500000-1709383500000.csv
# Records/Records-TORNTPOWER-1677748500000-1709383740000.csv
# Records/Records-VOLTAS-1677748500000-1709383740000.csv
# Records/Records-RAMCOCEM-1677748500000-1709383560000.csv
# Records/Records-MSUMI-1677748500000-1709383740000.csv
# Records/Records-YESBANK-1677748500000-1709383740000.csv
# Records/Records-ESCORTS-1677748500000-1709383380000.csv
# Records/Records-BDL-1677748500000-1709383680000.csv
# Records/Records-JSWENERGY-1677748500000-1709383680000.csv
# Records/Records-PAGEIND-1677748500000-1709383500000.csv
# Records/Records-TATAELXSI-1677748500000-1709383620000.csv
# Records/Records-FORTIS-1677748500000-1709383440000.csv
# Records/Records-KPITTECH-1677748500000-1709383740000.csv
# Records/Records-GLAND-1677748500000-1709383380000.csv
# Records/Records-NHPC-1677748500000-1709383740000.csv
# Records/Records-BANDHANBNK-1677748500000-1709383740000.csv
# Records/Records-JUBLFOOD-1677748500000-1709383740000.csv
# Records/Records-BIOCON-1677748500000-1709383740000.csv
# Records/Records-NMDC-1677748500000-1709383680000.csv
# Records/Records-RVNL-1677748500000-1709383740000.csv
# Records/Records-LTTS-1677748500000-1709383620000.csv
# Records/Records-ASTRAL-1677748500000-1709383740000.csv
# Records/Records-OIL-1677748500000-1709383740000.csv
# Records/Records-POLICYBZR-1677748500000-1709383500000.csv
# Records/Records-FACT-1677748500000-1709383560000.csv
# Records/Records-IPCALAB-1677748500000-1709383560000.csv
# Records/Records-ASHOKLEY-1677748500000-1709383740000.csv
# Records/Records-DIXON-1677748500000-1709383740000.csv
# Records/Records-DEVYANI-1677748500000-1709383620000.csv
# Records/Records-INDUSTOWER-1677748500000-1709383740000.csv
# Records/Records-BHEL-1677748500000-1709383740000.csv
# Records/Records-PATANJALI-1677748500000-1709383680000.csv
# Records/Records-INDIANB-1677748500000-1709383740000.csv
# Records/Records-CUMMINSIND-1677748500000-1709383740000.csv
# Records/Records-HINDPETRO-1677748500000-1709383740000.csv
# Records/Records-TATACHEM-1677748500000-1709383740000.csv
# Records/Records-DALBHARAT-1677748500000-1709383320000.csv
# Records/Records-DELHIVERY-1677748500000-1709383620000.csv
# Records/Records-BANKINDIA-1677748500000-1709383740000.csv
# Records/Records-APLAPOLLO-1677748500000-1709383620000.csv
# Records/Records-ZEEL-1677748500000-1709383740000.csv
# Records/Records-UNIONBANK-1677748500000-1709383740000.csv
# Records/Records-APOLLOTYRE-1677748500000-1709383740000.csv
# Records/Records-COFORGE-1677748500000-1709383440000.csv
# Records/Records-PFC-1677748500000-1709383740000.csv
# Records/Records-LALPATHLAB-1677748500000-1709383560000.csv
# Records/Records-RECLTD-1677748500000-1709383740000.csv
# Records/Records-MANKIND-1683625500000-1709383740000.csv
# Records/Records-MRF-1677748500000-1709383500000.csv
# Records/Records-CROMPTON-1677748500000-1709383740000.csv
# Records/Records-SYNGENE-1677748500000-1709383740000.csv
# Records/Records-AUBANK-1677748500000-1709383740000.csv
# Records/Records-LAURUSLABS-1677748500000-1709383740000.csv
# Records/Records-MFSL-1677748500000-1709383620000.csv
# Records/Records-HDFCAMC-1677748500000-1709383680000.csv
# Records/Records-IGL-1677748500000-1709383680000.csv
# Records/Records-FEDERALBNK-1677748500000-1709383740000.csv
# Records/Records-INDHOTEL-1677748500000-1709383620000.csv
# Records/Records-UBL-1677748500000-1709383380000.csv
# Records/Records-BALKRISIND-1677748500000-1709383200000.csv
# Records/Records-COROMANDEL-1677748500000-1709383680000.csv
# Records/Records-MAXHEALTH-1677748500000-1709383740000.csv
# Records/Records-FLUOROCHEM-1677748500000-1709383380000.csv
# Records/Records-PRESTIGE-1677748500000-1709383740000.csv
# Records/Records-AUROPHARMA-1677748500000-1709383740000.csv
# Records/Records-ALKEM-1677748500000-1709383680000.csv
# Records/Records-POLYCAB-1677748500000-1709383740000.csv
# Records/Records-PERSISTENT-1677748500000-1709383680000.csv
# Records/Records-TATAMOTORS-1677748500000-1709383740000.csv
# Records/Records-OBEROIRLTY-1677748500000-1709383620000.csv
# Records/Records-BATAINDIA-1677748500000-1709383740000.csv
# Records/Records-ABFRL-1677748500000-1709383680000.csv
# Records/Records-POONAWALLA-1677748500000-1709383740000.csv
# Records/Records-IDFCFIRSTB-1677748500000-1709383740000.csv
# Records/Records-LICHSGFIN-1677748500000-1709383500000.csv
# Records/Records-GODREJPROP-1677748500000-1709383740000.csv
# Records/Records-CGPOWER-1677748500000-1709383740000.csv
# Records/Records-NYKAA-1677748500000-1709383680000.csv
# Records/Records-BHARATFORG-1677748500000-1709383740000.csv
# Records/Records-SONACOMS-1677748500000-1709383740000.csv
# Records/Records-SUNTV-1677748500000-1709383380000.csv
# Records/Records-SAIL-1677748500000-1709383740000.csv
# Records/Records-GUJGASLTD-1677748500000-1709383680000.csv
# Records/Records-PAYTM-1677748500000-1709383740000.csv
# Records/Records-MPHASIS-1677748500000-1709383740000.csv

# %%
display(dfs[0])
# Out:
#                      time      open      high       low     close    volume  \
# 359   2023-03-02 15:14:00  0.997048  0.994768  0.999343  0.996723  0.067736
# 360   2023-03-02 15:15:00  0.997704  0.994768  0.998356  0.996723  0.208290
# 361   2023-03-02 15:16:00  0.997048  0.995422  0.999014  0.997379  0.135095
# 362   2023-03-02 15:17:00  0.998360  0.995422  1.000000  0.996723  0.056762
# 363   2023-03-02 15:18:00  0.997704  0.999673  1.000000  1.000655  0.569823
# ...                   ...       ...       ...       ...       ...       ...
# 92835 2024-03-02 12:42:00  1.224992  1.221387  1.227811  1.223788  0.000000
# 92836 2024-03-02 12:43:00  1.224992  1.221387  1.227811  1.223788  0.000000
# 92837 2024-03-02 12:44:00  1.224992  1.221387  1.227811  1.223788  0.000000
# 92838 2024-03-02 12:45:00  1.224992  1.221387  1.227811  1.223788  0.000000
# 92839 2024-03-02 12:48:00  1.224992  1.221387  1.227811  1.223788  0.000011
#
#          SMA_10    EMA_10   SMA_day   EMA_day     RSI_14      MACD  \
# 359    0.996232  0.996186  0.993510  0.993510  56.309484  0.000243
# 360    0.996298  0.996284  0.993501  0.993528  56.309484  0.000271
# 361    0.996429  0.996483  0.993482  0.993549  60.490521  0.000343
# 362    0.996461  0.996527  0.993460  0.993566  54.838933  0.000342
# 363    0.996887  0.997277  0.993458  0.993606  71.839404  0.000652
# ...         ...       ...       ...       ...        ...       ...
# 92835  1.223788  1.223660  1.221711  1.220160  50.223898 -0.000061
# 92836  1.223788  1.223683  1.221741  1.220180  50.223898 -0.000048
# 92837  1.223755  1.223702  1.221770  1.220200  50.223898 -0.000038
# 92838  1.223689  1.223718  1.221788  1.220220  50.223898 -0.000029
# 92839  1.223624  1.223730  1.221804  1.220240  50.223898 -0.000022
#
#        MACD_signal  MACD_hist
# 359       0.000219   0.000024
# 360       0.000230   0.000042
# 361       0.000252   0.000090
# 362       0.000270   0.000072
# 363       0.000346   0.000305
# ...            ...        ...
# 92835    -0.000016  -0.000046
# 92836    -0.000022  -0.000026
# 92837    -0.000025  -0.000012
# 92838    -0.000026  -0.000003
# 92839    -0.000025   0.000004
#
# [92481 rows x 14 columns]

# %%
# !python -m pip install "stable-baselines3" "huggingface_sb3"
# !conda search -c conda-forge *baseline*

# %%
import gymnasium as gym
from gymnasium import spaces
import numpy as np
import random
# import gym
# from gym import spaces
# import numpy as np

class ContinuousStockTradingEnv(gym.Env):
    """A stock trading environment for OpenAI gym with continuous action space"""
    metadata = {'render.modes': ['human']}
    
    def __init__(self, dfs):
        super(ContinuousStockTradingEnv, self).__init__()
        self.dfs = dfs
        self.df = self.dfs[random.randint(1, len(self.dfs))]
        
        # Initial conditions
        self.initial_balance = 1000
        self.current_balance = self.initial_balance
        
        self.df = self.df.drop('time', axis=1)

        # self.df = df  # DataFrame containing the stock data
        self.max_steps = len(self.df)
        self.current_step = 0
        
        # Define action and observation space
        # Actions of the format: number of shares to buy (positive) or sell (negative)
        current_price = self.df.iloc[self.current_step]['close']
        max_buyable_shares = int(self.current_balance / current_price)
        
        self.action_space = spaces.Discrete(11)  # 21 discrete actions

        # Map index to action value (-20 to +20 with gaps of 2)
        # self.action_map = np.arange(-20, 21, 2)  # This creates an array [-20, -18, ..., 18, 20]

        # Observation space using the five provided features (Open, High, Low, Close, Volume)
        self.observation_space = spaces.Box(low=0, high=float('inf'), shape=(13,), dtype=np.float32)
        
        self.holding = 0

    def step(self, action):
        truncated = False
        # print('action', action)
        # Update the current step
        self.current_step += 1

        action = (action - 20)*2
        
        # Get the current stock data
        current_data = self.df.iloc[self.current_step]
        current_price = current_data['close']  # Assuming we use the closing price for transactions

        # action = int(round(action))
    
        # Calculate the maximum number of shares we can buy
        current_price = self.df.iloc[self.current_step]['close']
        # print(current_price, self.current_balance)
        # print(self.current_balance, current_price)
        if current_price > 0:
            max_buyable_shares = int(self.current_balance / current_price)
        else:
            max_buyable_shares = 20
        # if max_buyable_shares == 0:
        #     truncated = True
    
        # Ensure the action is within bounds
        # action = np.clip(action, -self.holding, max_buyable_shares)
        
        # Execute the trade
        trade_value = action * current_price
        self.current_balance -= trade_value  # If action is negative, this increases balance
        self.holding += action  # Update the number of shares held

        print('self.holding, trade_value, self.current_balance', self.holding, trade_value, self.current_balance)
        portfolio_value = self.current_balance + self.holding * current_price

        reward = portfolio_value - (self.initial_balance + self.holding * current_data['open'])
        
        # Check if the episode is done
        done = self.current_step >= self.max_steps - 1

        # Optionally include additional info
        info = {}
        return current_data.values, reward, done, truncated, info

    def reset(self, **kwargs):
        # Reset the environment state for a new episode
        self.current_step = 0
        self.current_balance = self.initial_balance
        self.holding = 0
        
        self.df = self.dfs[random.randint(1, len(self.dfs))]
        self.df = self.df.drop('time', axis=1)
        
        self.max_steps = len(self.df)
        # print(self.df.iloc[self.current_step].values.shape)
        return [self.df.iloc[self.current_step].values, None]

    def render(self, mode='human', close=False):
        # Render the environment to the screen (optional)
        pass

# %%
env = ContinuousStockTradingEnv(dfs)

observations = env.reset()
print(observations)
done = False
while not done:
    # Random action: buy/sell a random number of shares
    action = np.random.uniform(0, 11, (1, 1))[0][0]  # Adjust the range based on expected max trading volume
    # print(env.action_map)
    # print(env.action_space)
    # print(action)
    observations, reward, done, t, info = env.step(action)
    # print(observations)
    print(f"Step: {env.current_step}, Action: {action}, Reward: {reward}, Portfolio Value: {env.current_balance + env.holding * observations[3]}")  # Observations[3] is the 'Close' price
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

env = ContinuousStockTradingEnv(dfs)

model = PPO("MlpPolicy", env, verbose=1, device='mps')
# model = PPO.load("ppo_stock_trading")

# Train the model
print('starting training')
total_timesteps = 20000  # Adjust based on your needs
model.learn(total_timesteps=total_timesteps)

model.save("ppo_stock_trading_v2")
print('saved model')
# Out:
# Using mps device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# starting training
# -----------------------------
# | time/              |      |
# |    fps             | 60   |
# |    iterations      | 1    |
# |    time_elapsed    | 33   |
# |    total_timesteps | 2048 |
# -----------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 46             |
# |    iterations           | 2              |
# |    time_elapsed         | 87             |
# |    total_timesteps      | 4096           |
# | train/                  |                |
# |    approx_kl            | -2.0198058e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.4           |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.88e+11       |
# |    n_updates            | 10             |
# |    policy_gradient_loss | -8.41e-06      |
# |    value_loss           | 3.64e+11       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 43            |
# |    iterations           | 3             |
# |    time_elapsed         | 141           |
# |    total_timesteps      | 6144          |
# | train/                  |               |
# |    approx_kl            | -4.505273e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.4          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.39e+12      |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -2.82e-06     |
# |    value_loss           | 2.54e+12      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 41             |
# |    iterations           | 4              |
# |    time_elapsed         | 195            |
# |    total_timesteps      | 8192           |
# | train/                  |                |
# |    approx_kl            | -4.4732587e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.4           |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.45e+12       |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -1.35e-06      |
# |    value_loss           | 6.89e+12       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 40             |
# |    iterations           | 5              |
# |    time_elapsed         | 250            |
# |    total_timesteps      | 10240          |
# | train/                  |                |
# |    approx_kl            | -4.5110937e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.4           |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 6.63e+12       |
# |    n_updates            | 40             |
# |    policy_gradient_loss | -6.97e-07      |
# |    value_loss           | 1.32e+13       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 40            |
# |    iterations           | 6             |
# |    time_elapsed         | 305           |
# |    total_timesteps      | 12288         |
# | train/                  |               |
# |    approx_kl            | -4.263711e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.4          |
# |    explained_variance   | 0             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.09e+13      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -1.64e-06     |
# |    value_loss           | 2.19e+13      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 39             |
# |    iterations           | 7              |
# |    time_elapsed         | 359            |
# |    total_timesteps      | 14336          |
# | train/                  |                |
# |    approx_kl            | -4.3888576e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.4           |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 1.64e+13       |
# |    n_updates            | 60             |
# |    policy_gradient_loss | -6.07e-07      |
# |    value_loss           | 3.33e+13       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 39             |
# |    iterations           | 8              |
# |    time_elapsed         | 413            |
# |    total_timesteps      | 16384          |
# | train/                  |                |
# |    approx_kl            | -4.0134182e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.4           |
# |    explained_variance   | -1.19e-07      |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.3e+13        |
# |    n_updates            | 70             |
# |    policy_gradient_loss | -9.98e-08      |
# |    value_loss           | 4.73e+13       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 39             |
# |    iterations           | 9              |
# |    time_elapsed         | 467            |
# |    total_timesteps      | 18432          |
# | train/                  |                |
# |    approx_kl            | -3.8940925e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.4           |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.22e+13       |
# |    n_updates            | 80             |
# |    policy_gradient_loss | -1.28e-07      |
# |    value_loss           | 6.44e+13       |
# --------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 39             |
# |    iterations           | 10             |
# |    time_elapsed         | 522            |
# |    total_timesteps      | 20480          |
# | train/                  |                |
# |    approx_kl            | -5.2823452e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -2.4           |
# |    explained_variance   | 0              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 4.26e+13       |
# |    n_updates            | 90             |
# |    policy_gradient_loss | -1.36e-07      |
# |    value_loss           | 8.4e+13        |
# --------------------------------------------
# saved model

# %%
# Optionally, test the trained model
env = ContinuousStockTradingEnv(dfs)

model = PPO.load("ppo_stock_trading_v2")

obs, _  = env.reset()
print(obs)
for _ in range(1000):
    # print(obs)
    action, _states = model.predict(obs, deterministic=True)
    print(type(action), action)
    # print((action[0]))
    # print(type(action))
    # print(round(action))
    # print(action)
    obs, rewards, done, truncated, info = env.step(action)
    print(reward)
    # env.render()  # If your environment supports rendering
# Out:
# [ 9.91695244e-01  9.94383415e-01  9.93871636e-01  9.94699793e-01
#   4.98809524e-01  9.94749482e-01  9.94781171e-01  9.95670232e-01
#   9.95670232e-01  4.58324260e+01 -4.80164684e-04 -3.80674822e-04
#  -9.94898626e-05]
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -32 -31.83966873706004 1031.83966873706
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -64 -31.850269151138715 1063.6899378881988
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -96 -31.801242236024844 1095.4911801242235
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -128 -31.85424430641822 1127.3454244306417
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -160 -31.83701863354037 1159.182443064182
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -192 -31.825093167701866 1191.007536231884
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -214 -21.884306418219463 1212.8918426501034
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -246 -31.827743271221532 1244.719585921325
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -278 -31.83834368530021 1276.5579296066253
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -310 -31.852919254658385 1308.4108488612837
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -332 -21.902525879917185 1330.313374741201
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -354 -21.890683229813664 1352.2040579710147
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -386 -31.846293995859213 1384.050351966874
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -418 -31.827743271221532 1415.8780952380955
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -450 -31.86616977225673 1447.7442650103521
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -472 -22.02004140786749 1469.7643064182196
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -494 -21.991801242236026 1491.7561076604557
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -516 -22.01366459627329 1513.7697722567289
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -538 -21.994534161490684 1535.7643064182196
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -560 -22.01093167701863 1557.7752380952381
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -582 -22.015486542443064 1579.7907246376813
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -604 -21.99817805383023 1601.7889026915116
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -626 -21.959006211180125 1623.7479089026917
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -648 -21.954451345755693 1645.7023602484473
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -680 -31.961573498964803 1677.663933747412
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -702 -21.975403726708077 1699.63933747412
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -724 -21.972670807453415 1721.6120082815735
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -746 -21.999089026915115 1743.6110973084885
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -768 -22.036438923395444 1765.647536231884
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -790 -22.046459627329195 1787.6939958592131
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -812 -22.07287784679089 1809.766873706004
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -834 -22.060124223602482 1831.8269979296065
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -856 -22.026418219461696 1853.8534161490682
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -878 -22.017308488612837 1875.870724637681
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -900 -21.990890269151137 1897.861614906832
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -932 -31.986749482401656 1929.8483643892337
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -964 -32.00662525879917 1961.8549896480329
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -996 -32.018550724637684 1993.8735403726705
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -1018 -21.994534161490684 2015.8680745341612
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1050 -31.96554865424431 2047.8336231884055
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1082 -31.986749482401656 2079.820372670807
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1114 -31.985424430641825 2111.8057971014487
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1146 -31.93374741200828 2143.739544513457
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1178 -31.90989648033126 2175.649440993788
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1210 -31.94302277432712 2207.5924637681155
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1242 -31.946997929606624 2239.5394616977223
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1274 -31.95494824016563 2271.494409937888
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1306 -31.946997929606624 2303.441407867495
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1338 -31.94832298136646 2335.3897308488613
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1370 -31.895320910973084 2367.2850517598345
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1402 -31.897971014492757 2399.183022774327
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1434 -31.93374741200828 2431.1167701863355
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1466 -31.886045548654245 2463.00281573499
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1498 -31.893995859213252 2494.896811594203
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1530 -31.901946169772256 2526.798757763975
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1562 -31.93242236024845 2558.7311801242236
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1594 -31.912546583850933 2590.6437267080746
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1626 -31.96687370600414 2622.610600414079
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1658 -31.960248447204968 2654.5708488612836
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1690 -31.960248447204968 2686.5310973084884
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -1712 -21.969937888198757 2708.501035196687
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1744 -31.980124223602484 2740.4811594202897
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -1766 -21.965383022774326 2762.446542443064
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1798 -31.978799171842653 2794.4253416149068
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -1820 -21.990890269151137 2816.416231884058
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -1842 -21.989979296066256 2838.4062111801245
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -1864 -21.983602484472048 2860.3898136645967
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1896 -31.985424430641825 2892.3752380952383
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -1918 -21.98815734989648 2914.3633954451348
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -1940 -21.973581780538304 2936.336977225673
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -1972 -31.96687370600414 2968.303850931677
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2004 -31.952298136645965 3000.256149068323
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2036 -31.946997929606624 3032.2031469979297
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2068 -31.891345755693585 3064.0944927536234
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2100 -31.883395445134575 3095.977888198758
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2132 -31.867494824016564 3127.8453830227745
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2164 -31.891345755693585 3159.736728778468
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2196 -31.893995859213252 3191.6307246376814
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2228 -31.919171842650105 3223.5498964803314
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2260 -31.913871635610764 3255.463768115942
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2292 -31.895320910973084 3287.359089026915
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2324 -31.931097308488614 3319.2901863354036
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2356 -31.936397515527947 3351.2265838509315
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2388 -31.93374741200828 3383.16033126294
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2420 -31.93374741200828 3415.0940786749484
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2452 -31.952298136645965 3447.046376811594
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -2474 -21.963561076604556 3469.0099378881987
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2506 -31.945672877846793 3500.9556107660455
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2538 -31.944347826086958 3532.8999585921324
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2570 -31.953623188405796 3564.853581780538
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -2592 -21.95080745341615 3586.804389233954
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2624 -31.928447204968943 3618.732836438923
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2656 -31.952298136645965 3650.685134575569
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2688 -31.952298136645965 3682.637432712215
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -2710 -21.966293995859214 3704.603726708074
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2742 -31.93374741200828 3736.5374741200826
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2774 -31.9575983436853 3768.495072463768
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -2796 -21.928033126293997 3790.423105590062
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2828 -31.897971014492757 3822.3210766045545
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2860 -31.928447204968943 3854.2495238095235
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2892 -31.928447204968943 3886.1779710144924
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2924 -31.929772256728775 3918.1077432712214
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2956 -31.929772256728775 3950.0375155279503
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -2988 -31.913871635610764 3981.951387163561
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3020 -31.919171842650105 4013.870559006211
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3052 -31.920496894409936 4045.791055900621
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3084 -31.93374741200828 4077.7248033126293
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3116 -31.929772256728775 4109.654575569358
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3148 -31.913871635610764 4141.568447204969
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3180 -31.92712215320911 4173.495569358178
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3212 -31.919171842650105 4205.414741200828
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3244 -31.912546583850933 4237.327287784678
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3276 -31.937722567287786 4269.265010351966
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3308 -31.931097308488614 4301.196107660455
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3340 -31.88207039337474 4333.078178053829
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3372 -31.868819875776396 4364.9469979296055
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3404 -31.893995859213252 4396.840993788819
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3436 -31.862194616977224 4428.703188405796
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3468 -31.87146997929607 4460.574658385092
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3500 -31.84496894409938 4492.419627329192
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3532 -31.8303933747412 4524.250020703933
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3564 -31.822443064182192 4556.072463768115
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3596 -31.77606625258799 4587.848530020703
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3628 -31.801242236024844 4619.649772256728
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3660 -31.79329192546584 4651.443064182195
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3692 -31.806542443064185 4683.249606625259
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3724 -31.807867494824016 4715.057474120083
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3756 -31.81979296066253 4746.877267080745
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3788 -31.807867494824016 4778.685134575569
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3820 -31.84894409937888 4810.5340786749475
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3852 -31.850269151138715 4842.384347826086
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3884 -31.84894409937888 4874.233291925465
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3916 -31.83834368530021 4906.071635610765
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -3948 -31.880745341614908 4937.95238095238
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -3970 -21.91072463768116 4959.863105590061
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4002 -31.880745341614908 4991.743850931676
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4024 -21.961739130434783 5013.705590062111
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4046 -21.977225672877847 5035.682815734988
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4068 -21.972670807453415 5057.655486542441
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4090 -21.954451345755693 5079.609937888197
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4112 -21.968115942028984 5101.578053830226
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4134 -21.972670807453415 5123.550724637679
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4156 -21.966293995859214 5145.517018633538
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4178 -21.97175983436853 5167.488778467907
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4200 -21.969026915113872 5189.457805383021
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4222 -21.954451345755693 5211.412256728777
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4244 -21.954451345755693 5233.366708074533
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4266 -21.954451345755693 5255.3211594202885
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4288 -21.954451345755693 5277.275610766044
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4310 -21.954451345755693 5299.2300621118
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4332 -21.968115942028984 5321.198178053829
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4354 -21.97175983436853 5343.169937888198
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4376 -21.967204968944102 5365.137142857142
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4398 -21.954451345755693 5387.091594202898
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4430 -31.946997929606624 5419.038592132504
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4452 -21.974492753623185 5441.013084886127
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4474 -21.981780538302278 5462.99486542443
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4496 -21.973581780538304 5484.9684472049685
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4518 -21.979047619047616 5506.947494824016
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4540 -21.999089026915115 5528.946583850931
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4562 -22.01366459627329 5550.960248447204
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4584 -21.983602484472048 5572.943850931676
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4606 -21.954451345755693 5594.898302277432
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -4628 -21.94989648033126 5616.848198757763
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4660 -31.9112215320911 5648.7594202898545
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4692 -31.86351966873706 5680.622939958592
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4724 -31.858219461697725 5712.481159420289
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4756 -31.87809523809524 5744.359254658384
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4788 -31.850269151138715 5776.209523809523
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4820 -31.850269151138715 5808.059792960661
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4852 -31.850269151138715 5839.9100621118
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4884 -31.850269151138715 5871.760331262938
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4916 -31.850269151138715 5903.6106004140765
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4948 -31.875445134575568 5935.486045548652
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -4980 -31.842318840579708 5967.328364389232
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5012 -31.852919254658385 5999.18128364389
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5044 -31.823768115942027 6031.005051759832
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5076 -31.8264182194617 6062.831469979294
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5108 -31.8264182194617 6094.657888198755
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5140 -31.827743271221532 6126.485631469976
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5172 -31.827743271221532 6158.313374741198
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5204 -31.846293995859213 6190.159668737057
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5236 -31.846293995859213 6222.005962732916
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5268 -31.80521739130435 6253.81118012422
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5300 -31.801242236024844 6285.612422360246
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -5322 -21.865175983436853 6307.477598343682
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5354 -31.80521739130435 6339.282815734987
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5386 -31.801242236024844 6371.084057971012
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5418 -31.80256728778468 6402.886625258797
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5450 -31.801242236024844 6434.687867494822
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5482 -31.801242236024844 6466.489109730847
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5514 -31.813167701863357 6498.302277432711
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5546 -31.795942028985507 6530.098219461696
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5578 -31.777391304347823 6561.875610766044
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5610 -31.825093167701866 6593.700703933746
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5642 -31.801242236024844 6625.501946169771
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5674 -31.810517598343683 6657.312463768115
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5706 -31.807867494824016 6689.120331262939
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5738 -31.801242236024844 6720.921573498964
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -5760 -21.86335403726708 6742.784927536231
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5792 -31.801242236024844 6774.586169772257
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5824 -31.801242236024844 6806.387412008282
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5856 -31.774741200828156 6838.16215320911
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5888 -31.795942028985507 6869.958095238096
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5920 -31.798592132505178 6901.756687370601
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5952 -31.801242236024844 6933.557929606626
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -5984 -31.784016563146995 6965.341946169773
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6016 -31.77871635610766 6997.120662525881
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6048 -31.77871635610766 7028.899378881989
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6080 -31.758840579710146 7060.658219461699
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6112 -31.74824016563147 7092.406459627331
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6144 -31.773416149068325 7124.179875776399
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6176 -31.777391304347823 7155.9572670807465
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6208 -31.768115942028984 7187.7253830227755
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6240 -31.768115942028984 7219.4934989648045
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6272 -31.791966873706006 7251.28546583851
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6304 -31.78136645962733 7283.066832298137
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6336 -31.806542443064185 7314.873374741202
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -6358 -21.857888198757767 7336.731262939959
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6390 -31.77076604554865 7368.502028985508
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6422 -31.784016563146995 7400.286045548655
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6454 -31.784016563146995 7432.070062111802
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6486 -31.77871635610766 7463.84877846791
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6518 -31.773416149068325 7495.622194616978
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6550 -31.752215320910974 7527.374409937889
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6582 -31.74824016563147 7559.122650103521
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6614 -31.74824016563147 7590.870890269152
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6646 -31.752215320910974 7622.6231055900635
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6678 -31.74824016563147 7654.371345755695
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6710 -31.74824016563147 7686.119585921327
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6742 -31.724389233954447 7717.843975155281
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6774 -31.724389233954447 7749.568364389236
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6806 -31.721739130434784 7781.290103519671
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6838 -31.721739130434784 7813.011842650106
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6870 -31.72041407867495 7844.732256728781
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6902 -31.721739130434784 7876.453995859216
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6934 -31.72703933747412 7908.18103519669
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6966 -31.734989648033125 7939.916024844722
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -6998 -31.80389233954451 7971.719917184267
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7020 -21.86335403726708 7993.583271221534
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7042 -21.86335403726708 8015.446625258802
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7064 -21.878840579710143 8037.325465838512
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7086 -21.899792960662527 8059.225258799174
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7108 -21.918923395445134 8081.144182194619
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7130 -21.901614906832297 8103.045797101451
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7152 -21.91072463768116 8124.956521739133
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7174 -21.85697722567288 8146.813498964806
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7196 -21.844223602484472 8168.657722567291
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7228 -31.733664596273293 8200.391387163565
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7260 -31.75486542443064 8232.146252587996
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7292 -31.75486542443064 8263.901118012427
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7324 -31.75354037267081 8295.654658385098
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7356 -31.74824016563147 8327.402898550728
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7388 -31.728364389233956 8359.131262939962
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7420 -31.72571428571429 8390.856977225676
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7452 -31.745590062111802 8422.602567287788
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7484 -31.733664596273293 8454.33623188406
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7516 -31.723064182194616 8486.059296066256
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7548 -31.721739130434784 8517.781035196691
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7580 -31.728364389233956 8549.509399585924
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7612 -31.728364389233956 8581.237763975158
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7644 -31.721739130434784 8612.959503105592
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7676 -31.721739130434784 8644.681242236027
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7708 -31.74293995859213 8676.42418219462
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7740 -31.721739130434784 8708.145921325055
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7772 -31.73763975155279 8739.883561076607
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7804 -31.73763975155279 8771.62120082816
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7836 -31.73763975155279 8803.358840579713
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7868 -31.721739130434784 8835.080579710148
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7900 -31.721739130434784 8866.802318840582
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7932 -31.721739130434784 8898.524057971017
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -7964 -31.791966873706006 8930.316024844724
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -7986 -21.872463768115942 8952.18848861284
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8008 -21.890683229813664 8974.079171842654
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8030 -21.877018633540374 8995.956190476194
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8052 -21.894327122153207 9017.850517598346
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8074 -21.906169772256728 9039.756687370604
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8096 -21.8424016563147 9061.599089026919
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8128 -31.795942028985507 9093.395031055905
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8150 -21.897971014492754 9115.293002070397
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8172 -21.87792960662526 9137.170931677023
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8194 -21.892505175983437 9159.063436853006
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8216 -21.88977225672878 9180.953209109735
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8238 -21.895238095238096 9202.848447204973
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8260 -21.882484472049686 9224.730931677022
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8282 -21.882484472049686 9246.613416149072
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8304 -21.894327122153207 9268.507743271224
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8326 -21.881573498964805 9290.389316770188
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8348 -21.85697722567288 9312.24629399586
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8380 -31.76016563146998 9344.00645962733
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8412 -31.789316770186336 9375.795776397516
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8444 -31.827743271221532 9407.623519668738
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8466 -21.881573498964805 9429.505093167701
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8488 -21.86335403726708 9451.368447204968
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8520 -31.80919254658385 9483.177639751551
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8552 -31.81979296066253 9514.997432712215
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8584 -31.81979296066253 9546.817225672878
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8616 -31.85424430641822 9578.671469979296
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8638 -21.899792960662527 9600.571262939959
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8660 -21.917101449275364 9622.488364389234
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8682 -21.882484472049686 9644.370848861283
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8704 -21.864265010351968 9666.235113871635
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8736 -31.80256728778468 9698.03768115942
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8768 -31.847619047619048 9729.88530020704
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8790 -21.89614906832298 9751.781449275362
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8812 -21.901614906832297 9773.683064182194
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8834 -21.894327122153207 9795.577391304347
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8856 -21.899792960662527 9817.47718426501
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8878 -21.901614906832297 9839.378799171842
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8900 -21.872463768115942 9861.251262939957
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -8922 -21.885217391304348 9883.13648033126
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8954 -31.8303933747412 9914.966873706002
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -8986 -31.8264182194617 9946.793291925464
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9018 -31.843643892339543 9978.636935817804
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9040 -21.895238095238096 10000.532173913041
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9072 -31.823768115942027 10032.355942028984
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9094 -21.895238095238096 10054.251180124222
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9126 -31.850269151138715 10086.10144927536
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9158 -31.852919254658385 10117.954368530018
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9180 -21.902525879917185 10139.856894409935
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9202 -21.908902691511386 10161.765797101447
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9224 -21.91072463768116 10183.676521739128
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9246 -21.888861283643894 10205.565383022771
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9278 -31.846293995859213 10237.41167701863
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9310 -31.843643892339543 10269.25532091097
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9342 -31.84894409937888 10301.104265010348
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9374 -31.850269151138715 10332.954534161487
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9396 -21.917101449275364 10354.871635610762
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9418 -21.907080745341617 10376.778716356102
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9440 -21.917101449275364 10398.695817805377
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9462 -21.911635610766048 10420.607453416143
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9484 -21.901614906832297 10442.509068322976
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9506 -21.890683229813664 10464.39975155279
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9538 -31.822443064182192 10496.222194616972
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9570 -31.835693581780536 10528.057888198753
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9602 -31.835693581780536 10559.893581780534
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9634 -31.81581780538302 10591.709399585918
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9666 -31.81979296066253 10623.52919254658
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9698 -31.81449275362319 10655.343685300204
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9730 -31.81979296066253 10687.163478260867
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9762 -31.868819875776396 10719.032298136644
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -9784 -21.864265010351968 10740.896563146996
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9816 -31.80389233954451 10772.700455486542
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9848 -31.801242236024844 10804.501697722566
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9880 -31.801242236024844 10836.30293995859
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9912 -31.773416149068325 10868.076356107658
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9944 -31.774741200828156 10899.851097308487
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -9976 -31.773416149068325 10931.624513457555
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -10008 -31.77076604554865 10963.395279503104
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# ...
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25000 -32.214658385093166 26024.38865424434
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25032 -32.22260869565218 26056.61126293999
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25064 -32.20670807453416 26088.817971014523
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25096 -32.20935817805383 26121.027329192577
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25128 -32.19875776397515 26153.22608695655
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25160 -32.18815734989648 26185.41424430645
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25192 -32.18815734989648 26217.602401656346
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25224 -32.16165631469979 26249.764057971046
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25256 -32.14708074534161 26281.911138716387
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25288 -32.14973084886129 26314.060869565248
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25320 -32.119254658385096 26346.180124223632
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25352 -32.10467908902692 26378.28480331266
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25384 -32.11262939958592 26410.39743271225
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25416 -32.10335403726708 26442.500786749515
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25448 -32.067577639751555 26474.568364389266
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25480 -32.07817805383023 26506.646542443097
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25512 -32.05167701863354 26538.69821946173
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25544 -32.058302277432716 26570.756521739164
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25576 -32.08215320910973 26602.838674948274
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25608 -32.079503105590064 26634.918178053864
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25640 -32.070227743271225 26666.988405797136
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25672 -32.070227743271225 26699.058633540408
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25704 -32.03975155279503 26731.098385093203
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25736 -32.02650103519669 26763.1248861284
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25768 -32.02517598343685 26795.150062111836
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25800 -32.04107660455487 26827.19113871639
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25832 -32.03445134575569 26859.225590062146
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25864 -32.02252587991718 26891.248115942064
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25896 -32.03975155279503 26923.28786749486
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25928 -32.03975155279503 26955.327619047654
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25960 -32.03975155279503 26987.36737060045
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -25992 -32.02120082815735 27019.388571428604
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26024 -32.033126293995856 27051.4216977226
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26056 -32.03047619047619 27083.452173913076
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26088 -32.02385093167702 27115.476024844753
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26120 -32.0384265010352 27147.51445134579
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26152 -32.013250517598344 27179.527701863386
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26184 -32.03975155279503 27211.56745341618
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26216 -32.02252587991718 27243.5899792961
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26248 -31.986749482401656 27275.576728778502
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26280 -32.003975155279505 27307.58070393378
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26312 -32.02252587991718 27339.6032298137
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26344 -32.02120082815735 27371.624430641856
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26376 -31.97614906832298 27403.60057971018
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26408 -31.961573498964803 27435.562153209143
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26440 -31.95494824016563 27467.51710144931
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26472 -32.02252587991718 27499.539627329228
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26504 -32.0 27531.539627329228
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26536 -32.001325051759835 27563.540952380987
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26568 -31.98807453416149 27595.52902691515
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26600 -31.99072463768116 27627.51975155283
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26632 -32.02252587991718 27659.54227743275
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26664 -32.02650103519669 27691.568778467947
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26696 -32.0384265010352 27723.607204968983
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26728 -32.018550724637684 27755.62575569362
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26760 -31.980124223602484 27787.605879917224
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26792 -31.970848861283645 27819.57672877851
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26824 -31.974824016563147 27851.551552795074
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26856 -31.96554865424431 27883.517101449317
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26888 -31.986749482401656 27915.50385093172
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26920 -31.989399585921323 27947.49325051764
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26952 -31.980124223602484 27979.473374741243
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -26984 -31.980124223602484 28011.453498964845
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27016 -31.969523809523807 28043.42302277437
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27048 -31.960248447204968 28075.383271221574
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27080 -31.980124223602484 28107.363395445176
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27112 -31.968198757763975 28139.33159420294
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27144 -31.980124223602484 28171.311718426543
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27176 -31.968198757763975 28203.279917184307
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27208 -31.98409937888199 28235.26401656319
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27240 -31.98409937888199 28267.24811594207
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27272 -31.986749482401656 28299.234865424474
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27304 -31.985424430641825 28331.220289855115
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27336 -31.97217391304348 28363.19246376816
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27368 -31.93374741200828 28395.126211180166
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27400 -31.940372670807452 28427.066583850974
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27432 -31.970848861283645 28459.03743271226
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27464 -31.961573498964803 28490.999006211223
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27496 -31.961573498964803 28522.960579710187
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27528 -31.93904761904762 28554.899627329236
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27560 -31.978799171842653 28586.87842650108
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27592 -31.96554865424431 28618.843975155323
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27624 -31.969523809523807 28650.813498964846
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27656 -31.9575983436853 28682.77109730853
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27688 -31.9575983436853 28714.728695652215
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27720 -31.944347826086958 28746.673043478302
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -27752 -31.985424430641825 28778.658467908943
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27774 -21.99817805383023 28800.656645962772
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27796 -22.02186335403727 28822.67850931681
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27818 -22.02186335403727 28844.70037267085
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27840 -22.02186335403727 28866.72223602489
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27862 -22.02186335403727 28888.744099378928
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27884 -22.034616977225674 28910.778716356155
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27906 -22.01275362318841 28932.791469979344
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27928 -22.040993788819875 28954.832463768165
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27950 -22.03552795031056 28976.867991718475
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27972 -22.038260869565214 28998.90625258804
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -27994 -22.04008281573499 29020.946335403776
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -28016 -22.01184265010352 29042.95817805388
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28048 -32.04107660455487 29074.999254658433
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -28070 -22.02824016563147 29097.027494824066
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -28092 -22.026418219461696 29119.053913043528
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -28114 -22.02368530020704 29141.077598343734
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -28136 -22.018219461697722 29163.09581780543
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28168 -32.01590062111801 29195.11171842655
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28200 -32.02517598343685 29227.136894409985
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28232 -32.033126293995856 29259.17002070398
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28264 -32.02915113871635 29291.199171842694
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28296 -32.02915113871635 29323.22832298141
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28328 -32.03710144927536 29355.265424430683
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -28350 -22.024596273291923 29377.290020703975
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28382 -32.0463768115942 29409.33639751557
# 3017015.5548087754
# <class 'numpy.ndarray'> 9
# self.holding, trade_value, self.current_balance -28404 -22.02550724637681 29431.361904761947
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28436 -32.01192546583851 29463.373830227785
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28468 -32.02252587991718 29495.396356107703
# 3017015.5548087754
# <class 'numpy.ndarray'> 4
# self.holding, trade_value, self.current_balance -28500 -32.033126293995856 29527.429482401698
# 3017015.5548087754
